# %%
# Load necessary packages

import pandas as pd
import numpy as np
import sklearn
import matplotlib.pyplot as plt
import time
# %matplotlib inline

import random
from datetime import datetime

# %%
# Read data and present
tr_url = "https://raw.githubusercontent.com/maxuw/CardGame/master/trainingData.csv"
va_url = "https://raw.githubusercontent.com/maxuw/CardGame/master/validationData.csv"

train = pd.read_csv(tr_url)
valid = pd.read_csv(va_url)

# %%
# Helper functions to preprocess data to bag-of-cards format

def unnest(df, col):
    unnested = (df.apply(lambda x: pd.Series(x[col]), axis=1)
                .stack()
                .reset_index(level=1, drop=True))
    unnested.name = col
    return df.drop(col, axis=1).join(unnested)

def to_bag_of_cards(df):
    df['ind'] = np.arange(df.shape[0])# + 1
    df_orig = df.copy()
    df['deck'] = df['deck'].apply(lambda d: d.split(';'))
    df = unnest(df, 'deck')
    df['value'] = 1
    df_bag = df.pivot(index='ind', columns='deck', values='value')
    df_bag[df_bag.isna()] = 0
    df_bag = df_bag.astype('int')
    return pd.concat([df_orig.set_index('ind'), df_bag], axis=1)

# %%
bag_train = to_bag_of_cards(train)
bag_valid = to_bag_of_cards(valid)

# %%
valid.head()
# Out:
#                                                 deck  nofGames  nOfPlayers  \
# 0  [archers, arrows, baby-dragon, bandit, elixir-...       130          32
# 1  [archers, arrows, baby-dragon, elixir-collecto...       495          75
# 2  [archers, arrows, baby-dragon, golem, lightnin...       271          25
# 3  [archers, arrows, baby-dragon, golem, lightnin...       125          20
# 4  [archers, arrows, balloon, barbarians, firebal...       130          23
#
#    winRate  ind
# 0  0.48496    0
# 1  0.47289    1
# 2  0.52372    2
# 3  0.58594    3
# 4  0.50000    4

# %%
# Specify example model fitting function and R squared metric

from sklearn.svm import SVR

def R2(x, y):
    return 1 - np.sum(np.square(x - y)) / np.sum(np.square(y - np.mean(y)))

def fit_svm(data):
    svr = SVR(kernel='rbf', gamma=1.0/90, C=1.0, epsilon=0.02, shrinking=False)
    svr.fit(data.drop(['deck', 'nofGames', 'nOfPlayers', 'winRate'], axis=1), data['winRate'])
    return svr

# %%
sizes = (np.arange(10) + 6) * 100
sizes
# Out:
# array([ 600,  700,  800,  900, 1000, 1100, 1200, 1300, 1400, 1500])

# %%
# Fit and predict on models of various training sizes

fit_list = list(map(lambda size: fit_svm(train.iloc[:size]), sizes))
pred_list = list(map(lambda fit: fit.predict(valid.drop(['deck', 'nofGames', 'nOfPlayers', 'winRate'], axis=1)),
                     fit_list))

# %%
# Calculate R squared scores

r2 = list(map(lambda p: R2(p, valid['winRate']), pred_list))
r2
# Out:
# [-0.04232767917971958,
#  -0.03963921576228091,
#  -0.05090293576042337,
#  -0.06619693197263166,
#  -0.06891790332198067,
#  -0.0635866399958771,
#  -0.08254572245137948,
#  -0.07526826771478623,
#  -0.08499150250986709,
#  -0.0792418181864003]

# %%
# Save hyperparameteres and selected indices in submission format

with open('example_sub_python.txt', 'a') as f:
    for size in sizes:
        ind_text = ','.join(list(map(str, train.index.values[:size])))
        text = ';'.join(['0.02', '1.0', str(1.0 / 90), ind_text])
        f.write(text + '\n')

# %%
def train_predict(deck):
    model = fit_svm(deck)
    pred = model.predict(bag_valid.drop(['deck', 'nofGames', 'nOfPlayers', 'winRate'], axis=1))
    r2 = R2(pred, valid['winRate'])
    
    return r2

# %%
# Sort games by something

train = train.sort_values('nofGames', ascending=False)

# %%
train_subset = pd.DataFrame()

# %%
train_subset = train_subset.append(train.sort_values('nofGames', ascending=False)[:200])
train_subset = train_subset.append(train.sort_values('nOfPlayers', ascending=False)[:200])
train_subset = train_subset.append(train.sort_values('winRate', ascending=False)[:200])

# %%
train.sort_values('nofGames', ascending=False)[:200].shape
# Out:
# (200, 5)

# %%
r2_scores = []

start = time.time()
for i in range(len(bag_train)):
    pred = train_predict(train.loc[i:i])
    r2_scores.append(pred)
end = time.time()
print (end - start)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-1e76eb18f0cb> in <module>
#       3 start = time.time()
#       4 for i in range(len(bag_train)):
# ----> 5     pred = train_predict(train.loc[i:i])
#       6     r2_scores.append(pred)
#       7 end = time.time()
#
# <ipython-input-11-693b7a9ff171> in train_predict(deck)
#       1 def train_predict(deck):
#       2     model = fit_svm(deck)
# ----> 3     pred = model.predict(bag_valid.drop(['deck', 'nofGames', 'nOfPlayers', 'winRate'], axis=1))
#       4     r2 = R2(pred, valid['winRate'])
#       5
#
# ~/anaconda3/envs/nlpkeras/lib/python3.7/site-packages/sklearn/svm/base.py in predict(self, X)
#     320         y_pred : array, shape (n_samples,)
#     321         """
# --> 322         X = self._validate_for_predict(X)
#     323         predict = self._sparse_predict if self._sparse else self._dense_predict
#     324         return predict(X)
#
# ~/anaconda3/envs/nlpkeras/lib/python3.7/site-packages/sklearn/svm/base.py in _validate_for_predict(self, X)
#     472             raise ValueError("X.shape[1] = %d should be equal to %d, "
#     473                              "the number of features at training time" %
# --> 474                              (n_features, self.shape_fit_[1]))
#     475         return X
#     476
#
# ValueError: X.shape[1] = 90 should be equal to 1, the number of features at training time

# %%
def forward_search(data, num_initial_elements, step_size, desired_size):
    start_time = datetime.now()
    
    elements = set()
    
    while len(elements) < num_initial_elements:
        random_element = random.randint(0, len(data)-1)
        elements.add(random_element)

    initial_data = data.loc[elements]
    
    data_working = initial_data
    
    start = 0
    
    element_ended = 0
    
    while len(elements) < desired_size:
        
        elem_tentative = elements
        
        r2_current = train_predict(data_working)
        
        r2_temp_dict = {}
        
        for i in range(step_size):
            j = i + element_ended
#             print(j)
            
            if j not in elements:

                data_tentative = data_working
                data_tentative = data_tentative.append(data.loc[j:j])
#                 print(data.loc[j:j])
                
                r2_temp = train_predict(data_tentative)
                r2_temp_dict[j] = r2_temp
#                 print(r2_temp)
            
        max_elem = max(zip(r2_temp_dict.values(), r2_temp_dict.keys()))[1]
        
        elements.add(max_elem)
        print("adding {}".format(max_elem))
        data_working = data_working.append(data.loc[max_elem:max_elem])
        
        element_ended = element_ended + step_size
        
    end_time = datetime.now()
    time_taken = end_time - start_time
    print('Time: ', time_taken)
    
    return elements

# %%
def forward_search_smaller(data, index_subset, num_initial_elements, desired_size, step_size = 0):
    
    data = data.loc[index_subset]
    
    if step_size == 0:
        step_size = int(float(len(index_subset)/desired_size))
#         print("desired_size :", desired_size)
#         print("num index_subset :", index_subset)
        print("counted stepsize is :", step_size)
    
    start_time = datetime.now()
    
#     elements = set()
    
    elements = random.sample(index_subset, num_initial_elements)
    print(type(elements))

    initial_data = data.loc[elements]
    
    data_working = initial_data
    
    start = 0
    
    element_ended = 0
    
    while len(elements) < desired_size:
        
        elem_tentative = elements
        
        r2_current = train_predict(data_working)
        
        r2_temp_dict = {}
        
        
        
        for i in index_subset:
            if i not in elements:
                
                bucket_set = set()

                data_tentative = data_working
                data_tentative = data_tentative.append(data.loc[i:i])
    #                 print(data.loc[j:j])


                r2_temp = train_predict(data_tentative)
                r2_temp_dict[i] = r2_temp
    #                 print(r2_temp)
                if len(r2_temp_dict) >= step_size:
                    
                
                
                    max_elem = max(zip(r2_temp_dict.values(), r2_temp_dict.keys()))[1]

                    elements.append(max_elem)
                    
                    data_working = data_working.append(data.loc[max_elem:max_elem])
                    
                    print("adding {}".format(max_elem))
                    
                    r2_temp_dict = {}


        
                
        
    end_time = datetime.now()
    time_taken = end_time - start_time
    print('Time: ', time_taken)
    
    list_elements = list(elements)
    list_elements.sort()
    
    return elements

# %%
def forward_search_continue(data, initial_indexes, step_size, desired_size):
    start_time = datetime.now()
    
    elements = set()
    
    while len(elements) < num_initial_elements:
        random_element = random.randint(0, len(data)-1)
        elements.add(random_element)

    initial_data = data.loc[elements]
    
    data_working = initial_data
    
    start = 0
    
    element_ended = 0
    
    while len(elements) < desired_size:
        
        elem_tentative = elements
        
        r2_current = train_predict(data_working)
        
        r2_temp_dict = {}
        
        for i in range(step_size):
            j = i + element_ended
#             print(j)
            
            if j not in elements:

                data_tentative = data_working
                data_tentative = data_tentative.append(data.loc[j:j])
#                 print(data.loc[j:j])
                
                r2_temp = train_predict(data_tentative)
                r2_temp_dict[j] = r2_temp
#                 print(r2_temp)
            
        max_elem = max(zip(r2_temp_dict.values(), r2_temp_dict.keys()))[1]
        
        elements.add(max_elem)
        print("adding {}".format(max_elem))
        data_working = data_working.append(data.loc[max_elem:max_elem])
        
        element_ended = element_ended + step_size
        
    end_time = datetime.now()
    time_taken = end_time - start_time
    print('Time: ', time_taken)
    
    return data_working

# %%
# forward_search_2000 = forward_search(bag_train, 10, 50, 2000)

# %%
forward_search_try.shape

# %%
indexes = forward_search_try.index.values

# %%
def s(filename, obj):
    with open(filename, 'w') as f:
        for item in obj:
            f.write("%s\n % item)
    
    print("file saved")

# %%
def forward_search_seconds(data, num_initial_elements, step_size, desired_size):
    start_time = datetime.now()
    
    elements_best = set()
    seconds = set()
    thirds = set()
    fourths = set()
    
    while len(elements_best) < num_initial_elements:
        random_element = random.randint(0, len(data)-1)
        elements_best.add(random_element)

    initial_data = data.loc[elements_best]
    
    data_working = initial_data
    
    start = 0
    
    element_ended = 0
    
    while len(elements_best) < desired_size:
        
        elem_tentative = elements_best
        
        r2_current = train_predict(data_working)
        
        r2_temp_dict = {}
        
        for i in range(step_size):
            j = i + element_ended
#           
            if j == len(data):
                break
            
            if j not in elements_best:

                data_tentative = data_working
                data_tentative = data_tentative.append(data.loc[j:j])
#                 print(data.loc[j:j])
                
                r2_temp = train_predict(data_tentative)
                r2_temp_dict[j] = r2_temp
#                 print(r2_temp)
            
        max_elem = max(zip(r2_temp_dict.values(), r2_temp_dict.keys()))[1] 
        
        elements_best.add(max_elem)
        print("adding {}".format(max_elem))
        
        print("max elem", max_elem, "trying to delete")
        del r2_temp_dict[max_elem]
        
        if max_elem not in elements_best:
            print("dupa: nie ma elementu")
            
        print("drugi największy")
        max_elem = max(zip(r2_temp_dict.values(), r2_temp_dict.keys()))[1]
        seconds.add(max_elem)
        
        print("max elem", max_elem, "trying to delete")
        del r2_temp_dict[max_elem]
        
        if max_elem not in seconds:
            print("dupa: nie ma elementu")
        
        max_elem = max(zip(r2_temp_dict.values(), r2_temp_dict.keys()))[1]
        thirds.add(max_elem)
        
        print("max elem", max_elem, "trying to delete")
        del r2_temp_dict[max_elem]
        
        if max_elem not in thirds:
            print("dupa: nie ma elementu")
        
        max_elem = max(zip(r2_temp_dict.values(), r2_temp_dict.keys()))[1]
        fourths.add(max_elem)
        
        element_ended = element_ended + step_size
        
    end_time = datetime.now()
    time_taken = end_time - start_time
    print('Time: ', time_taken)
    
    dict_lists = {}
    dict_lists[1] = elements_best
    dict_lists[2] = seconds
    dict_lists[3] = thirds
    dict_lists[4] = fourths
    
    return dict_lists

# %%
def save_file(obj):
    if type(obj) == dict:
        print("It's a dict")
        
        obj_pd = pandas.DataFrame(obj)
        
    elif type(obj)  == list:
        obj_

# %%
save_file(forward_seconds_10000)
# Out:
# It's a dict

# %%
s("file1.txt", forward_seconds_10000[1])
# Out:
# file saved

# %%
def r(filename):
    list_obj = []
    with open(filename, 'r') as f:
        for line in f:
            list_obj.append(line)
    
    if filename:
        print("file read")
        
    return list_obj

# %%
jan1 = np.loadtxt("Jan_dumps/random_ind.out")

# %%
jan1 = jan1.astype(int)

# %%
type(jan1)
# Out:
# list

# %%
jan1 = jan1.tolist()

# %%
jan1

# %%
jan2 = np.loadtxt("Jan_dumps/random_ind_2.out")

# %%
jan3 = np.loadtxt("Jan_dumps/random_ind_3.out")

# %%
jan2
# Out:
# array([67494., 25351., 44297., ..., 98186., 98211., 98328.])

# %%
jan3
# Out:
# array([24865., 79172., 73581., ..., 98178., 98208., 98279.])

# %%
train_predict(bag_train.loc[jan1])
# Out:
# 0.32406572266974865

# %%
train_predict(bag_train.loc[jan2])
# Out:
# 0.30734180608557127

# %%
train_predict(bag_train.loc[jan3])
# Out:
# 0.3202908916237952

# %%
#jan1

# %%
def make_all_sets(ind_in):
    sizes_without_last = [600,  700,  800,  900, 1000, 1100, 1200, 1300, 1400]
    dict_sets = dict()
    for size in sizes:
        indexes_found = forward_search_smaller(bag_train, ind_in, num_initial_elements=5, desired_size=size)

        dict_sets[size] = indexes_found
    dict_sets[1500] = ind_in
    return dict_sets

# %%
jan1_sets = make_all_sets(jan1)
# Out:
# counted stepsize is : 2
# <class 'list'>
# adding 81380
# adding 74377
# adding 22035
# adding 18585
# adding 90558
# adding 89
# adding 176
# adding 384
# adding 396
# adding 624
# adding 686
# adding 842
# adding 932
# adding 1135
# adding 1217
# adding 1345
# adding 1553
# adding 1689
# adding 1827
# adding 1924
# adding 2073
# adding 2132
# adding 2317
# adding 2377
# adding 2571
# adding 2770
# adding 2837
# adding 2942
# adding 3143
# adding 3242
# adding 3428
# adding 3557
# adding 3735
# adding 3848
# adding 4022
# adding 4032
# adding 4162
# adding 4306
# adding 4540
# adding 4586
# adding 4812
# adding 4875
# adding 4995
# adding 5119
# adding 5279
# adding 5458
# adding 5559
# adding 5741
# adding 5872
# adding 5897
# adding 6136
# adding 6267
# adding 6367
# adding 6471
# adding 6626
# adding 6738
# adding 6878
# adding 7048
# adding 7192
# adding 7257
# adding 7378
# adding 7532
# adding 7654
# adding 7830
# adding 7941
# adding 8100
# adding 8220
# adding 8381
# adding 8510
# adding 8542
# adding 8749
# adding 8844
# adding 8970
# adding 9116
# adding 9304
# adding 9403
# adding 9509
# adding 9581
# adding 9809
# adding 9894
# adding 10013
# adding 10224
# adding 10360
# adding 10490
# adding 10559
# adding 10729
# adding 10827
# adding 10967
# adding 11119
# adding 11231
# adding 11301
# adding 11461
# adding 11560
# adding 11717
# adding 11909
# adding 12026
# adding 12118
# adding 12212
# adding 12461
# adding 12513
# adding 12679
# adding 12868
# adding 12893
# adding 13082
# adding 13188
# adding 13375
# adding 13489
# adding 13536
# adding 13697
# adding 13859
# adding 14015
# adding 14074
# adding 14278
# adding 14324
# adding 14476
# adding 14647
# adding 14842
# adding 14979
# adding 15039
# adding 15152
# adding 15251
# adding 15509
# adding 15540
# adding 15649
# adding 15905
# adding 15971
# adding 16166
# adding 16294
# adding 16431
# adding 16543
# adding 16661
# adding 16730
# adding 16890
# adding 17091
# adding 17225
# adding 17245
# adding 17504
# adding 17596
# adding 17817
# adding 17900
# adding 18041
# adding 18182
# adding 18228
# adding 18452
# adding 18482
# adding 18696
# adding 18806
# adding 18931
# adding 19048
# adding 19149
# adding 19351
# adding 19525
# adding 19667
# adding 19727
# adding 19844
# adding 19972
# adding 20166
# adding 20241
# adding 20340
# adding 20559
# adding 20687
# adding 20784
# adding 20864
# adding 21119
# adding 21226
# adding 21338
# adding 21476
# adding 21563
# adding 21746
# adding 21894
# adding 22019
# adding 22058
# adding 22254
# adding 22439
# adding 22447
# adding 22580
# adding 22761
# adding 22874
# adding 23051
# adding 23213
# adding 23326
# adding 23420
# adding 23624
# adding 23650
# adding 23790
# adding 23954
# adding 24089
# adding 24170
# adding 24416
# adding 24550
# adding 24638
# adding 24694
# adding 24819
# adding 24980
# adding 25108
# adding 25343
# adding 25453
# adding 25563
# adding 25770
# adding 25924
# adding 26065
# adding 26076
# adding 26236
# adding 26397
# adding 26595
# adding 26716
# adding 26858
# adding 26969
# adding 27081
# adding 27241
# adding 27306
# adding 27503
# adding 27564
# adding 27671
# adding 27837
# adding 27997
# adding 28179
# adding 28246
# adding 28441
# adding 28511
# adding 28689
# adding 28803
# adding 28970
# adding 29105
# adding 29168
# adding 29369
# adding 29433
# adding 29630
# adding 29759
# adding 29888
# adding 30029
# adding 30158
# adding 30242
# adding 30348
# adding 30546
# adding 30611
# adding 30747
# adding 30851
# adding 31011
# adding 31177
# adding 31282
# adding 31467
# adding 31541
# adding 31738
# adding 31786
# adding 31943
# adding 32141
# adding 32265
# adding 32294
# adding 32493
# adding 32575
# adding 32670
# adding 32928
# adding 33062
# adding 33107
# adding 33288
# adding 33426
# adding 33572
# adding 33682
# adding 33737
# adding 33893
# adding 34111
# adding 34126
# adding 34269
# adding 34476
# adding 34551
# adding 34752
# adding 34803
# adding 34971
# adding 35111
# adding 35306
# adding 35326
# adding 35559
# adding 35701
# adding 35746
# adding 35910
# adding 36067
# adding 36125
# adding 36299
# adding 36428
# adding 36560
# adding 36695
# adding 36853
# adding 36928
# adding 37109
# adding 37285
# adding 37332
# adding 37464
# adding 37682
# adding 37755
# adding 37925
# adding 38006
# adding 38152
# adding 38344
# adding 38426
# adding 38592
# adding 38638
# adding 38835
# adding 38962
# adding 39058
# adding 39177
# adding 39308
# adding 39450
# adding 39544
# adding 39718
# adding 39885
# adding 40003
# adding 40191
# adding 40323
# adding 40389
# adding 40564
# adding 40678
# adding 40758
# adding 40862
# adding 41105
# adding 41163
# adding 41298
# adding 41513
# adding 41642
# adding 41651
# adding 41792
# adding 42039
# adding 42043
# adding 42251
# adding 42346
# adding 42537
# adding 42662
# adding 42766
# adding 42950
# adding 43096
# adding 43192
# adding 43313
# adding 43382
# adding 43509
# adding 43752
# adding 43839
# adding 43981
# adding 44073
# adding 44258
# adding 44316
# adding 44517
# adding 44648
# adding 44694
# adding 44839
# adding 44995
# adding 45120
# adding 45273
# adding 45350
# adding 45541
# adding 45613
# adding 45818
# adding 45910
# adding 46059
# adding 46223
# adding 46359
# adding 46510
# adding 46618
# adding 46717
# adding 46854
# adding 47014
# adding 47131
# adding 47296
# adding 47385
# adding 47504
# adding 47681
# adding 47817
# adding 47858
# adding 48107
# adding 48232
# adding 48301
# adding 48487
# adding 48513
# adding 48743
# adding 48807
# adding 48936
# adding 49059
# adding 49193
# adding 49388
# adding 49446
# adding 49578
# adding 49701
# adding 49852
# adding 49995
# adding 50099
# adding 50292
# adding 50383
# adding 50548
# adding 50802
# adding 50910
# adding 51004
# adding 51087
# adding 51300
# adding 51399
# adding 51610
# adding 51740
# adding 51798
# adding 51891
# adding 52056
# adding 52154
# adding 52399
# adding 52512
# adding 52609
# adding 52682
# adding 52836
# adding 52948
# adding 53157
# adding 53289
# adding 53393
# adding 53516
# adding 53656
# adding 53849
# adding 53938
# adding 54027
# adding 54235
# adding 54379
# adding 54472
# adding 54622
# adding 54651
# adding 54856
# adding 55014
# adding 55147
# adding 55277
# adding 55369
# adding 55452
# adding 55667
# adding 55817
# adding 55959
# adding 56032
# adding 56230
# adding 56282
# adding 56415
# adding 56601
# adding 56650
# adding 56831
# adding 56940
# adding 57138
# adding 57281
# adding 57417
# adding 57551
# adding 57617
# adding 57797
# adding 57869
# adding 58070
# adding 58101
# adding 58310
# adding 58363
# adding 58478
# adding 58739
# adding 58868
# adding 58990
# adding 59119
# adding 59142
# adding 59394
# adding 59491
# adding 59628
# adding 59695
# adding 59920
# adding 59963
# adding 60127
# adding 60265
# adding 60362
# adding 60584
# adding 60600
# adding 60762
# adding 60983
# adding 61046
# adding 61140
# adding 61362
# adding 61451
# adding 61609
# adding 61658
# adding 61840
# adding 62017
# adding 62142
# adding 62261
# adding 62433
# adding 62521
# adding 62584
# adding 62780
# adding 62961
# adding 63046
# adding 63127
# adding 63293
# adding 63491
# adding 63524
# adding 63745
# adding 63796
# adding 64016
# adding 64151
# adding 64184
# adding 64299
# adding 64467
# adding 64625
# adding 64737
# adding 64887
# adding 64985
# adding 65160
# adding 65265
# adding 65469
# adding 65537
# adding 65612
# adding 65830
# adding 65897
# adding 66125
# adding 66225
# adding 66371
# adding 66407
# adding 66650
# adding 66666
# adding 66923
# adding 67054
# adding 67187
# adding 67253
# adding 67410
# adding 67461
# adding 67649
# adding 67781
# adding 67897
# adding 68011
# adding 68163
# adding 68359
# adding 68507
# adding 68570
# adding 68693
# adding 68825
# adding 68977
# adding 69101
# adding 69173
# adding 69323
# adding 69468
# adding 69639
# adding 69782
# adding 69837
# adding 70091
# adding 70150
# adding 70291
# adding 70409
# adding 70552
# adding 70724
# adding 70773
# adding 70982
# adding 71036
# adding 71279
# adding 71342
# adding 71487
# adding 71575
# adding 71739
# adding 71922
# adding 72011
# adding 72079
# adding 72246
# adding 72358
# adding 72498
# adding 72618
# adding 72759
# adding 72972
# adding 73075
# adding 73227
# adding 73260
# adding 73523
# adding 73655
# adding 73786
# adding 73915
# adding 73985
# adding 74096
# adding 74314
# adding 74381
# adding 74479
# adding 74669
# adding 74840
# adding 74971
# adding 75093
# adding 75238
# adding 75364
# adding 75436
# adding 75619
# adding 75758
# adding 75768
# adding 75997
# adding 76097
# adding 76203
# adding 76400
# adding 76538
# adding 76628
# adding 76765
# adding 76867
# adding 77087
# adding 77213
# adding 77348
# adding 77482
# adding 77497
# adding 77680
# adding 77771
# adding 78007
# adding 78142
# adding 78209
# adding 78292
# adding 78479
# adding 78588
# adding 78788
# adding 78808
# adding 79051
# adding 79082
# adding 79291
# adding 79459
# adding 79592
# adding 79725
# adding 79837
# adding 79953
# adding 80022
# adding 80219
# adding 80383
# adding 80418
# adding 80533
# adding 80686
# adding 80803
# adding 81012
# adding 81126
# adding 81303
# adding 81322
# adding 81513
# adding 81600
# adding 81831
# adding 81947
# adding 81986
# adding 82179
# adding 82267
# adding 82375
# adding 82556
# adding 82714
# adding 82786
# adding 82939
# adding 83154
# adding 83160
# adding 83375
# adding 83447
# adding 83687
# adding 83818
# adding 83909
# adding 84081
# adding 84102
# adding 84335
# adding 84375
# adding 84582
# adding 84672
# adding 84831
# adding 85007
# adding 85138
# adding 85202
# adding 85403
# adding 85533
# adding 85663
# adding 85799
# adding 85929
# adding 85989
# adding 86095
# adding 86197
# adding 86346
# adding 86560
# adding 86681
# adding 86854
# adding 86976
# adding 87114
# adding 87157
# adding 87279
# adding 87447
# adding 87551
# adding 87701
# adding 87868
# adding 87974
# adding 88115
# adding 88306
# adding 88432
# adding 88569
# adding 88748
# adding 88879
# adding 88986
# adding 89096
# adding 89296
# adding 89396
# adding 89523
# adding 89607
# adding 89748
# adding 89945
# adding 90087
# adding 90131
# adding 90346
# adding 90485
# adding 90617
# adding 90747
# adding 90872
# adding 90947
# adding 91050
# adding 91277
# adding 91405
# adding 91538
# adding 91666
# adding 91791
# adding 91935
# adding 92066
# adding 92200
# adding 92328
# adding 92465
# adding 92594
# adding 92725
# adding 92859
# adding 92862
# adding 93023
# adding 93251
# adding 93278
# adding 93518
# adding 93649
# adding 93782
# adding 93908
# adding 94034
# adding 94175
# adding 94309
# adding 94338
# adding 94476
# adding 94701
# adding 94838
# adding 94862
# adding 95043
# adding 95175
# adding 95312
# adding 95408
# adding 95591
# adding 95747
# adding 95837
# adding 95904
# adding 96125
# adding 96225
# adding 96334
# adding 96502
# adding 96621
# adding 96779
# adding 96840
# adding 96957
# adding 97217
# adding 97282
# adding 97481
# adding 97547
# adding 97711
# adding 97856
# adding 97966
# adding 98021
# adding 98186
# Time:  0:08:09.929574
# counted stepsize is : 2
# <class 'list'>
# adding 81380
# adding 74377
# adding 87565
# adding 18585
# adding 60799
# adding 89
# adding 176
# adding 268
# adding 396
# adding 537
# adding 686
# adding 842
# adding 932
# adding 1095
# adding 1217
# adding 1345
# adding 1498
# adding 1689
# adding 1827
# adding 1924
# adding 2023
# adding 2179
# adding 2317
# adding 2377
# adding 2631
# adding 2640
# adding 2845
# adding 2942
# adding 3060
# adding 3212
# adding 3350
# adding 3557
# adding 3569
# adding 3735
# adding 3906
# adding 4032
# adding 4145
# adding 4266
# adding 4473
# adding 4540
# adding 4654
# adding 4812
# adding 4995
# adding 5119
# adding 5279
# adding 5336
# adding 5495
# adding 5559
# adding 5773
# adding 5872
# adding 6000
# adding 6136
# adding 6367
# adding 6471
# adding 6538
# adding 6728
# adding 6878
# adding 6952
# adding 7103
# adding 7257
# adding 7378
# adding 7532
# adding 7654
# adding 7743
# adding 7941
# adding 8100
# adding 8220
# adding 8381
# adding 8510
# adding 8542
# adding 8749
# adding 8844
# adding 8970
# adding 9116
# adding 9304
# adding 9340
# adding 9509
# adding 9680
# adding 9809
# adding 9894
# adding 10013
# adding 10224
# adding 10360
# adding 10490
# adding 10603
# adding 10729
# adding 10760
# adding 10954
# adding 11119
# adding 11231
# adding 11301
# adding 11515
# adding 11677
# adding 11717
# adding 11821
# adding 12026
# adding 12118
# adding 12212
# adding 12461
# adding 12513
# adding 12665
# adding 12868
# adding 12893
# adding 13082
# adding 13260
# adding 13375
# adding 13489
# adding 13653
# adding 13790
# adding 13895
# adding 14015
# adding 14163
# adding 14278
# adding 14324
# adding 14579
# adding 14647
# adding 14842
# adding 14979
# adding 15074
# adding 15203
# adding 15251
# adding 15509
# adding 15540
# adding 15732
# adding 15905
# adding 15971
# adding 16166
# adding 16294
# adding 16431
# adding 16471
# adding 16661
# adding 16826
# adding 16961
# adding 17091
# adding 17225
# adding 17245
# adding 17452
# adding 17596
# adding 17753
# adding 17817
# adding 17900
# adding 18127
# adding 18228
# adding 18319
# adding 18452
# adding 18618
# adding 18806
# adding 18931
# adding 19048
# adding 19101
# adding 19272
# adding 19351
# adding 19525
# adding 19667
# adding 19770
# adding 19917
# adding 20049
# adding 20166
# adding 20297
# adding 20504
# adding 20559
# adding 20784
# adding 20864
# adding 21051
# adding 21119
# adding 21277
# adding 21338
# adding 21563
# adding 21670
# adding 21746
# adding 21913
# adding 22019
# adding 22120
# adding 22317
# adding 22439
# adding 22580
# adding 22761
# adding 22874
# adding 23033
# adding 23105
# adding 23237
# adding 23420
# adding 23560
# adding 23624
# adding 23696
# adding 23873
# adding 24003
# adding 24146
# adding 24269
# adding 24484
# adding 24550
# adding 24694
# adding 24754
# adding 24980
# adding 25059
# adding 25182
# adding 25343
# adding 25480
# adding 25563
# adding 25716
# adding 25924
# adding 26065
# adding 26176
# adding 26272
# adding 26453
# adding 26595
# adding 26716
# adding 26858
# adding 26969
# adding 27081
# adding 27241
# adding 27306
# adding 27450
# adding 27564
# adding 27671
# adding 27837
# adding 27997
# adding 28179
# adding 28246
# adding 28511
# adding 28578
# adding 28741
# adding 28803
# adding 28970
# adding 29105
# adding 29303
# adding 29433
# adding 29467
# adding 29698
# adding 29830
# adding 29961
# adding 30093
# adding 30175
# adding 30242
# adding 30488
# adding 30546
# adding 30649
# adding 30816
# adding 31011
# adding 31115
# adding 31177
# adding 31291
# adding 31541
# adding 31665
# adding 31786
# adding 31943
# adding 32034
# adding 32141
# adding 32265
# adding 32352
# adding 32493
# adding 32665
# adding 32815
# adding 32928
# adding 33107
# adding 33241
# adding 33353
# adding 33426
# adding 33572
# adding 33737
# adding 33857
# adding 33943
# adding 34111
# adding 34269
# adding 34368
# adding 34551
# adding 34698
# adding 34803
# adding 34861
# adding 35111
# adding 35233
# adding 35326
# adding 35444
# adding 35559
# adding 35701
# adding 35792
# adding 35910
# adding 36125
# adding 36184
# adding 36428
# adding 36436
# adding 36598
# adding 36823
# adding 36928
# adding 37068
# adding 37162
# adding 37332
# adding 37464
# adding 37618
# adding 37682
# adding 37881
# adding 38006
# adding 38092
# adding 38152
# adding 38344
# adding 38507
# adding 38638
# adding 38790
# adding 38835
# adding 39058
# adding 39074
# adding 39241
# adding 39397
# adding 39544
# adding 39647
# adding 39831
# adding 39992
# adding 40003
# adding 40257
# adding 40389
# adding 40454
# adding 40564
# adding 40758
# adding 40845
# adding 41046
# adding 41105
# adding 41298
# adding 41447
# adding 41579
# adding 41651
# adding 41768
# adding 41974
# adding 42039
# adding 42221
# adding 42251
# adding 42487
# adding 42591
# adding 42766
# adding 42773
# adding 43025
# adding 43138
# adding 43192
# adding 43382
# adding 43509
# adding 43635
# adding 43752
# adding 43839
# adding 43981
# adding 44122
# adding 44316
# adding 44470
# adding 44517
# adding 44694
# adding 44839
# adding 44902
# adding 45047
# adding 45273
# adding 45350
# adding 45436
# adding 45541
# adding 45695
# adding 45910
# adding 46059
# adding 46071
# adding 46223
# adding 46426
# adding 46578
# adding 46618
# adding 46854
# adding 46915
# adding 47014
# adding 47207
# adding 47385
# adding 47425
# adding 47581
# adding 47681
# adding 47817
# adding 47977
# adding 48107
# adding 48232
# adding 48395
# adding 48513
# adding 48684
# adding 48807
# adding 48888
# adding 49028
# adding 49154
# adding 49243
# adding 49388
# adding 49578
# adding 49701
# adding 49766
# adding 49898
# adding 50099
# adding 50211
# adding 50292
# adding 50484
# adding 50570
# adding 50705
# adding 50910
# adding 51033
# adding 51087
# adding 51300
# adding 51416
# adding 51610
# adding 51637
# adding 51843
# adding 51891
# adding 52126
# adding 52154
# adding 52399
# adding 52512
# adding 52542
# adding 52757
# adding 52911
# adding 53025
# adding 53064
# adding 53289
# adding 53393
# adding 53516
# adding 53658
# adding 53849
# adding 53871
# adding 54027
# adding 54289
# adding 54447
# adding 54528
# adding 54651
# adding 54817
# adding 54942
# adding 55014
# adding 55239
# adding 55369
# adding 55452
# adding 55633
# adding 55667
# adding 55817
# adding 56032
# adding 56099
# adding 56282
# adding 56415
# adding 56519
# adding 56601
# adding 56759
# adding 56940
# adding 57047
# adding 57138
# adding 57353
# adding 57484
# adding 57617
# adding 57678
# adding 57869
# adding 57990
# adding 58101
# adding 58235
# adding 58310
# adding 58478
# adding 58672
# adding 58760
# adding 58868
# adding 58990
# adding 59119
# adding 59332
# adding 59463
# adding 59491
# adding 59695
# adding 59752
# adding 59963
# adding 60050
# adding 60237
# adding 60265
# adding 60515
# adding 60584
# adding 60699
# adding 60829
# adding 61046
# adding 61140
# adding 61299
# adding 61398
# adding 61451
# adding 61609
# adding 61840
# adding 61858
# adding 62017
# adding 62195
# adding 62368
# adding 62447
# adding 62521
# adding 62647
# adding 62858
# adding 62961
# adding 63046
# adding 63204
# adding 63327
# adding 63491
# adding 63623
# adding 63796
# adding 63879
# adding 64056
# adding 64184
# adding 64299
# adding 64467
# adding 64496
# adding 64737
# adding 64802
# adding 64887
# adding 65108
# adding 65160
# adding 65281
# adding 65469
# adding 65612
# adding 65686
# adding 65830
# adding 66047
# adding 66182
# adding 66225
# adding 66407
# adding 66513
# adding 66666
# adding 66727
# adding 67054
# adding 67187
# adding 67253
# adding 67321
# adding 67461
# adding 67650
# adding 67782
# adding 67897
# adding 68048
# adding 68163
# adding 68359
# adding 68507
# adding 68607
# adding 68739
# adding 68859
# adding 68977
# adding 69165
# adding 69247
# adding 69323
# adding 69468
# adding 69639
# adding 69782
# adding 69837
# adding 70091
# adding 70150
# adding 70288
# adding 70482
# adding 70594
# adding 70667
# adding 70849
# adding 70949
# adding 71088
# adding 71187
# adding 71342
# adding 71487
# adding 71575
# adding 71739
# adding 71922
# adding 72079
# adding 72246
# adding 72358
# adding 72498
# adding 72590
# adding 72691
# adding 72835
# adding 73035
# adding 73075
# adding 73260
# adding 73456
# adding 73584
# adding 73721
# adding 73848
# adding 73985
# adding 74096
# adding 74155
# adding 74381
# adding 74438
# adding 74517
# adding 74669
# adding 74908
# adding 75037
# adding 75168
# adding 75238
# adding 75436
# adding 75558
# adding 75700
# adding 75768
# adding 75855
# adding 76097
# adding 76203
# adding 76277
# adding 76400
# adding 76538
# adding 76628
# adding 76765
# adding 76954
# adding 77152
# adding 77285
# adding 77411
# adding 77497
# adding 77560
# adding 77771
# adding 77895
# adding 78075
# adding 78209
# adding 78292
# adding 78383
# adding 78588
# adding 78640
# adding 78808
# adding 78870
# adding 79082
# adding 79191
# adding 79291
# adding 79459
# adding 79592
# adding 79725
# adding 79837
# adding 80022
# adding 80097
# adding 80219
# adding 80418
# adding 80471
# adding 80686
# adding 80803
# adding 80963
# adding 81113
# adding 81126
# adding 81322
# adding 81450
# adding 81600
# adding 81678
# adding 81831
# adding 81986
# adding 82119
# adding 82267
# adding 82375
# adding 82556
# adding 82606
# adding 82786
# adding 82865
# adding 83035
# adding 83154
# adding 83288
# adding 83447
# adding 83533
# adding 83750
# adding 83884
# adding 83983
# adding 84081
# adding 84279
# adding 84375
# adding 84542
# adding 84672
# adding 84758
# adding 84831
# adding 85067
# adding 85202
# adding 85337
# adding 85467
# adding 85600
# adding 85729
# adding 85861
# adding 85929
# adding 86095
# adding 86192
# adding 86327
# adding 86524
# adding 86560
# adding 86787
# adding 86854
# adding 87053
# adding 87114
# adding 87279
# adding 87447
# adding 87551
# adding 87626
# adding 87834
# adding 87974
# adding 88033
# adding 88239
# adding 88371
# adding 88505
# adding 88637
# adding 88748
# adding 88879
# adding 88960
# adding 89096
# adding 89296
# adding 89396
# adding 89493
# adding 89648
# adding 89748
# adding 89945
# adding 90087
# adding 90219
# adding 90346
# adding 90382
# adding 90617
# adding 90747
# adding 90872
# adding 90947
# adding 91144
# adding 91277
# adding 91405
# adding 91538
# adding 91594
# adding 91705
# adding 91871
# adding 92066
# adding 92200
# adding 92328
# adding 92465
# adding 92594
# adding 92725
# adding 92859
# adding 92862
# adding 93023
# adding 93251
# adding 93278
# adding 93518
# adding 93649
# adding 93782
# adding 93846
# adding 93926
# adding 94175
# adding 94309
# adding 94338
# adding 94476
# adding 94701
# adding 94838
# adding 94972
# adding 94992
# adding 95126
# adding 95312
# adding 95459
# adding 95591
# adding 95695
# adding 95837
# adding 95904
# adding 96125
# adding 96225
# adding 96416
# adding 96442
# adding 96621
# adding 96779
# adding 96840
# adding 96957
# adding 97217
# adding 97346
# adding 97481
# adding 97547
# adding 97666
# adding 97807
# adding 97966
# adding 98094
# adding 98186
# Time:  0:08:05.986202
# counted stepsize is : 1
# <class 'list'>
# adding 55491
# adding 81380
# adding 98341
# adding 74377
# adding 87565
# adding 22035
# adding 42838
# adding 18585
# adding 90558
# adding 60799
# adding 48
# adding 89
# adding 176
# adding 198
# adding 268
# adding 384
# adding 396
# adding 500
# adding 537
# adding 624
# adding 686
# adding 741
# adding 842
# adding 875
# adding 932
# adding 1035
# adding 1095
# adding 1135
# adding 1217
# adding 1288
# adding 1345
# adding 1403
# adding 1498
# adding 1553
# adding 1648
# adding 1689
# adding 1718
# adding 1827
# adding 1878
# adding 1924
# adding 2023
# adding 2073
# adding 2132
# adding 2179
# adding 2283
# adding 2317
# adding 2377
# adding 2469
# adding 2571
# adding 2631
# adding 2640
# adding 2770
# adding 2837
# adding 2845
# adding 2942
# adding 3012
# adding 3060
# adding 3143
# adding 3212
# adding 3242
# adding 3350
# adding 3428
# adding 3452
# adding 3557
# adding 3569
# adding 3634
# adding 3735
# adding 3780
# adding 3848
# adding 3906
# adding 4022
# adding 4032
# adding 4145
# adding 4162
# adding 4266
# adding 4306
# adding 4401
# adding 4473
# adding 4540
# adding 4586
# adding 4654
# adding 4729
# adding 4812
# adding 4875
# adding 4935
# adding 4995
# adding 5078
# adding 5119
# adding 5205
# adding 5279
# adding 5336
# adding 5351
# adding 5458
# adding 5495
# adding 5559
# adding 5664
# adding 5741
# adding 5773
# adding 5872
# adding 5897
# adding 6000
# adding 6070
# adding 6136
# adding 6189
# adding 6267
# adding 6321
# adding 6367
# adding 6448
# adding 6471
# adding 6538
# adding 6626
# adding 6728
# adding 6738
# adding 6809
# adding 6878
# adding 6952
# adding 7048
# adding 7103
# adding 7192
# adding 7257
# adding 7268
# adding 7378
# adding 7449
# adding 7517
# adding 7532
# adding 7654
# adding 7696
# adding 7743
# adding 7830
# adding 7914
# adding 7941
# adding 8044
# adding 8100
# adding 8167
# adding 8220
# adding 8278
# adding 8381
# adding 8446
# adding 8510
# adding 8542
# adding 8621
# adding 8706
# adding 8749
# adding 8784
# adding 8844
# adding 8970
# adding 8976
# adding 9098
# adding 9116
# adding 9174
# adding 9304
# adding 9340
# adding 9403
# adding 9443
# adding 9509
# adding 9581
# adding 9680
# adding 9710
# adding 9809
# adding 9894
# adding 9951
# adding 10013
# adding 10038
# adding 10158
# adding 10224
# adding 10293
# adding 10360
# adding 10422
# adding 10490
# adding 10559
# adding 10603
# adding 10687
# adding 10729
# adding 10760
# adding 10827
# adding 10954
# adding 10967
# adding 11067
# adding 11119
# adding 11158
# adding 11231
# adding 11301
# adding 11417
# adding 11461
# adding 11515
# adding 11560
# adding 11677
# adding 11717
# adding 11788
# adding 11821
# adding 11909
# adding 11961
# adding 12026
# adding 12118
# adding 12154
# adding 12212
# adding 12299
# adding 12403
# adding 12461
# adding 12513
# adding 12555
# adding 12665
# adding 12679
# adding 12797
# adding 12868
# adding 12893
# adding 12947
# adding 13015
# adding 13082
# adding 13188
# adding 13260
# adding 13318
# adding 13375
# adding 13460
# adding 13489
# adding 13536
# adding 13653
# adding 13697
# adding 13790
# adding 13859
# adding 13895
# adding 13931
# adding 14015
# adding 14074
# adding 14163
# adding 14232
# adding 14278
# adding 14324
# adding 14425
# adding 14476
# adding 14579
# adding 14647
# adding 14714
# adding 14775
# adding 14842
# adding 14853
# adding 14979
# adding 15039
# adding 15074
# adding 15152
# adding 15203
# adding 15251
# adding 15372
# adding 15426
# adding 15509
# adding 15540
# adding 15583
# adding 15649
# adding 15732
# adding 15833
# adding 15905
# adding 15971
# adding 16033
# adding 16103
# adding 16166
# adding 16232
# adding 16294
# adding 16367
# adding 16431
# adding 16471
# adding 16543
# adding 16568
# adding 16661
# adding 16730
# adding 16826
# adding 16890
# adding 16961
# adding 17024
# adding 17091
# adding 17156
# adding 17225
# adding 17245
# adding 17340
# adding 17414
# adding 17452
# adding 17504
# adding 17596
# adding 17684
# adding 17753
# adding 17817
# adding 17851
# adding 17900
# adding 17968
# adding 18041
# adding 18127
# adding 18182
# adding 18228
# adding 18319
# adding 18388
# adding 18452
# adding 18482
# adding 18604
# adding 18618
# adding 18696
# adding 18806
# adding 18859
# adding 18931
# adding 18973
# adding 19048
# adding 19101
# adding 19149
# adding 19235
# adding 19272
# adding 19351
# adding 19404
# adding 19525
# adding 19567
# adding 19667
# adding 19727
# adding 19770
# adding 19844
# adding 19917
# adding 19972
# adding 20049
# adding 20097
# adding 20241
# adding 20297
# adding 20340
# adding 20435
# adding 20504
# adding 20559
# adding 20639
# adding 20687
# adding 20784
# adding 20819
# adding 20864
# adding 20948
# adding 21051
# adding 21119
# adding 21125
# adding 21226
# adding 21277
# adding 21338
# adding 21440
# adding 21476
# adding 21563
# adding 21630
# adding 21670
# adding 21746
# adding 21823
# adding 21913
# adding 22019
# adding 22058
# adding 22120
# adding 22206
# adding 22254
# adding 22317
# adding 22439
# adding 22447
# adding 22568
# adding 22580
# adding 22676
# adding 22761
# adding 22802
# adding 22874
# adding 22934
# adding 23033
# adding 23051
# adding 23105
# adding 23213
# adding 23237
# adding 23326
# adding 23420
# adding 23464
# adding 23560
# adding 23624
# adding 23650
# adding 23696
# adding 23790
# adding 23873
# adding 23954
# adding 24003
# adding 24089
# adding 24146
# adding 24170
# adding 24269
# adding 24352
# adding 24416
# adding 24484
# adding 24550
# adding 24616
# adding 24638
# adding 24694
# adding 24754
# adding 24819
# adding 24946
# adding 24980
# adding 25059
# adding 25108
# adding 25182
# adding 25229
# adding 25343
# adding 25363
# adding 25453
# adding 25480
# adding 25563
# adding 25660
# adding 25716
# adding 25770
# adding 25837
# adding 25924
# adding 25957
# adding 26065
# adding 26076
# adding 26176
# adding 26236
# adding 26272
# adding 26397
# adding 26453
# adding 26503
# adding 26595
# adding 26607
# adding 26716
# adding 26779
# adding 26858
# adding 26906
# adding 26969
# adding 27055
# adding 27081
# adding 27190
# adding 27241
# adding 27306
# adding 27335
# adding 27450
# adding 27503
# adding 27564
# adding 27599
# adding 27671
# adding 27720
# adding 27837
# adding 27885
# adding 27936
# adding 27997
# adding 28105
# adding 28179
# adding 28246
# adding 28312
# adding 28377
# adding 28441
# adding 28511
# adding 28545
# adding 28578
# adding 28689
# adding 28741
# adding 28803
# adding 28904
# adding 28970
# adding 29035
# adding 29105
# adding 29168
# adding 29235
# adding 29303
# adding 29369
# adding 29433
# adding 29467
# adding 29561
# adding 29630
# adding 29759
# adding 29830
# adding 29888
# adding 29961
# adding 30029
# adding 30093
# adding 30158
# adding 30175
# adding 30242
# adding 30348
# adding 30399
# adding 30488
# adding 30546
# adding 30611
# adding 30649
# adding 30747
# adding 30816
# adding 30851
# adding 30923
# adding 31011
# adding 31022
# adding 31115
# adding 31177
# adding 31282
# adding 31291
# adding 31408
# adding 31467
# adding 31541
# adding 31552
# adding 31665
# adding 31738
# adding 31786
# adding 31876
# adding 31943
# adding 32003
# adding 32034
# adding 32141
# adding 32177
# adding 32265
# adding 32294
# adding 32352
# adding 32407
# adding 32493
# adding 32575
# adding 32665
# adding 32670
# adding 32761
# adding 32815
# adding 32928
# adding 32993
# adding 33062
# adding 33107
# adding 33173
# adding 33241
# adding 33288
# adding 33353
# adding 33426
# adding 33524
# adding 33572
# adding 33600
# adding 33682
# adding 33737
# adding 33857
# adding 33893
# adding 33943
# adding 34027
# adding 34111
# adding 34126
# adding 34219
# adding 34269
# adding 34368
# adding 34426
# adding 34476
# adding 34551
# adding 34600
# adding 34698
# adding 34752
# adding 34803
# adding 34861
# adding 34971
# adding 35020
# adding 35111
# adding 35155
# adding 35233
# adding 35306
# adding 35326
# adding 35441
# adding 35444
# adding 35559
# adding 35632
# adding 35701
# adding 35746
# adding 35792
# adding 35848
# adding 35910
# adding 36018
# adding 36067
# adding 36125
# adding 36184
# adding 36299
# adding 36361
# adding 36428
# adding 36436
# adding 36560
# adding 36598
# adding 36695
# adding 36719
# adding 36823
# adding 36853
# adding 36928
# adding 37022
# adding 37068
# adding 37109
# adding 37162
# adding 37285
# adding 37332
# adding 37378
# adding 37464
# adding 37525
# adding 37618
# adding 37682
# adding 37729
# adding 37755
# adding 37881
# adding 37925
# adding 38006
# adding 38034
# adding 38092
# adding 38152
# adding 38236
# adding 38344
# adding 38348
# adding 38426
# adding 38507
# adding 38592
# adding 38638
# adding 38683
# adding 38790
# adding 38835
# adding 38908
# adding 38962
# adding 39058
# adding 39074
# adding 39177
# adding 39241
# adding 39308
# adding 39397
# adding 39450
# adding 39532
# adding 39544
# adding 39647
# adding 39718
# adding 39753
# adding 39831
# adding 39885
# adding 39992
# adding 40003
# adding 40126
# adding 40191
# adding 40257
# adding 40323
# adding 40389
# adding 40454
# adding 40514
# adding 40564
# adding 40655
# adding 40678
# adding 40758
# adding 40845
# adding 40862
# adding 40931
# adding 41046
# adding 41105
# adding 41163
# adding 41241
# adding 41298
# adding 41371
# adding 41447
# adding 41513
# adding 41579
# adding 41642
# adding 41651
# adding 41768
# adding 41792
# adding 41907
# adding 41974
# adding 42039
# adding 42043
# adding 42137
# adding 42221
# adding 42251
# adding 42346
# adding 42420
# adding 42487
# adding 42537
# adding 42591
# adding 42662
# adding 42766
# adding 42773
# adding 42885
# adding 42950
# adding 43025
# adding 43096
# adding 43138
# adding 43192
# adding 43289
# adding 43313
# adding 43382
# adding 43482
# adding 43509
# adding 43610
# adding 43635
# adding 43752
# adding 43810
# adding 43839
# adding 43949
# adding 44073
# adding 44122
# adding 44210
# adding 44258
# adding 44316
# adding 44410
# adding 44470
# adding 44517
# adding 44601
# adding 44648
# adding 44694
# adding 44808
# adding 44839
# adding 44902
# adding 44995
# adding 45047
# adding 45120
# adding 45170
# adding 45273
# adding 45314
# adding 45350
# adding 45436
# adding 45522
# adding 45541
# adding 45613
# adding 45695
# adding 45745
# adding 45818
# adding 45910
# adding 45950
# adding 46059
# adding 46071
# adding 46176
# adding 46223
# adding 46327
# adding 46359
# adding 46426
# adding 46510
# adding 46578
# adding 46618
# adding 46717
# adding 46756
# adding 46854
# adding 46915
# adding 46958
# adding 47014
# adding 47080
# adding 47131
# adding 47207
# adding 47296
# adding 47385
# adding 47425
# adding 47504
# adding 47581
# adding 47612
# adding 47681
# adding 47738
# adding 47817
# adding 47858
# adding 47977
# adding 47992
# adding 48107
# adding 48150
# adding 48232
# adding 48301
# adding 48367
# adding 48395
# adding 48487
# adding 48513
# adding 48632
# adding 48684
# adding 48743
# adding 48807
# adding 48888
# adding 48936
# adding 49028
# adding 49059
# adding 49154
# adding 49193
# adding 49243
# adding 49306
# adding 49388
# adding 49446
# adding 49515
# adding 49578
# adding 49674
# adding 49701
# adding 49766
# adding 49852
# adding 49898
# adding 49995
# adding 50066
# adding 50099
# adding 50211
# adding 50276
# adding 50292
# adding 50383
# adding 50484
# adding 50548
# adding 50570
# adding 50686
# adding 50705
# adding 50802
# adding 50822
# adding 50910
# adding 51004
# adding 51033
# adding 51087
# adding 51189
# adding 51253
# adding 51300
# adding 51399
# adding 51416
# adding 51545
# adding 51610
# adding 51637
# adding 51740
# adding 51798
# adding 51843
# adding 51891
# adding 51962
# adding 52056
# adding 52126
# adding 52154
# adding 52206
# adding 52332
# adding 52399
# adding 52458
# adding 52512
# adding 52542
# adding 52609
# adding 52682
# adding 52757
# adding 52836
# adding 52911
# adding 52948
# adding 53025
# adding 53064
# adding 53157
# adding 53204
# adding 53289
# adding 53393
# adding 53412
# adding 53516
# adding 53581
# adding 53656
# adding 53658
# adding 53783
# adding 53849
# adding 53871
# adding 53938
# adding 54027
# adding 54110
# adding 54135
# adding 54235
# adding 54289
# adding 54379
# adding 54447
# adding 54472
# adding 54528
# adding 54622
# adding 54651
# adding 54736
# adding 54817
# adding 54856
# adding 54942
# adding 55014
# adding 55102
# adding 55147
# adding 55239
# adding 55277
# adding 55369
# adding 55427
# adding 55452
# adding 55570
# adding 55633
# adding 55667
# adding 55732
# adding 55817
# adding 55867
# adding 55959
# adding 56032
# adding 56099
# adding 56158
# adding 56230
# adding 56282
# adding 56312
# adding 56415
# adding 56451
# adding 56519
# adding 56601
# adding 56650
# adding 56759
# adding 56774
# adding 56831
# adding 56940
# adding 56964
# adding 57047
# adding 57138
# adding 57215
# adding 57281
# adding 57353
# adding 57417
# adding 57484
# adding 57551
# adding 57617
# adding 57678
# adding 57722
# adding 57797
# adding 57869
# adding 57930
# adding 57990
# adding 58070
# adding 58101
# adding 58190
# adding 58235
# adding 58310
# adding 58363
# adding 58422
# adding 58478
# adding 58576
# adding 58672
# adding 58739
# adding 58760
# adding 58868
# adding 58899
# adding 58990
# adding 59027
# adding 59119
# adding 59142
# adding 59234
# adding 59332
# adding 59394
# adding 59463
# adding 59491
# adding 59583
# adding 59628
# adding 59695
# adding 59752
# adding 59831
# adding 59920
# adding 59963
# adding 60050
# adding 60095
# adding 60127
# adding 60237
# adding 60265
# adding 60362
# adding 60443
# adding 60515
# adding 60584
# adding 60600
# adding 60699
# adding 60762
# adding 60829
# adding 60885
# adding 60983
# adding 61046
# adding 61115
# adding 61140
# adding 61191
# adding 61299
# adding 61362
# adding 61398
# adding 61451
# adding 61557
# adding 61609
# adding 61658
# adding 61717
# adding 61840
# adding 61858
# adding 61935
# adding 62017
# adding 62068
# adding 62142
# adding 62195
# adding 62261
# adding 62368
# adding 62433
# adding 62447
# adding 62521
# adding 62584
# adding 62647
# adding 62740
# adding 62780
# adding 62858
# adding 62961
# adding 63011
# adding 63046
# adding 63127
# adding 63204
# adding 63293
# adding 63327
# adding 63404
# adding 63491
# adding 63524
# adding 63623
# adding 63626
# adding 63745
# adding 63796
# adding 63879
# adding 63950
# adding 64016
# adding 64056
# adding 64151
# adding 64184
# adding 64255
# adding 64299
# adding 64406
# adding 64467
# adding 64496
# adding 64598
# adding 64625
# adding 64737
# adding 64802
# adding 64865
# adding 64887
# adding 64985
# adding 65043
# adding 65108
# adding 65160
# adding 65265
# adding 65281
# adding 65404
# adding 65469
# adding 65537
# adding 65540
# adding 65612
# adding 65686
# adding 65798
# adding 65830
# adding 65897
# adding 65974
# adding 66047
# adding 66125
# adding 66182
# adding 66225
# adding 66277
# adding 66371
# adding 66407
# adding 66513
# adding 66590
# adding 66650
# adding 66666
# adding 66727
# adding 66856
# adding 66923
# adding 66989
# adding 67054
# adding 67079
# adding 67187
# adding 67253
# adding 67279
# adding 67321
# adding 67410
# adding 67461
# adding 67530
# adding 67649
# adding 67650
# adding 67781
# adding 67782
# adding 67897
# adding 67976
# adding 68011
# adding 68048
# adding 68163
# adding 68225
# adding 68283
# adding 68359
# adding 68421
# adding 68507
# adding 68570
# adding 68607
# adding 68693
# adding 68739
# adding 68825
# adding 68859
# adding 68936
# adding 68977
# adding 69101
# adding 69165
# adding 69173
# adding 69247
# adding 69323
# adding 69369
# adding 69468
# adding 69561
# adding 69594
# adding 69639
# adding 69716
# adding 69782
# adding 69837
# adding 69900
# adding 70025
# adding 70091
# adding 70150
# adding 70182
# adding 70288
# adding 70291
# adding 70409
# adding 70482
# adding 70552
# adding 70594
# adding 70667
# adding 70724
# adding 70773
# adding 70849
# adding 70949
# adding 70982
# adding 71036
# adding 71088
# adding 71187
# adding 71279
# adding 71342
# adding 71385
# adding 71445
# adding 71487
# adding 71575
# adding 71641
# adding 71739
# adding 71753
# adding 71852
# adding 71922
# adding 71962
# adding 72011
# adding 72079
# adding 72192
# adding 72246
# adding 72294
# adding 72358
# adding 72461
# adding 72498
# adding 72590
# adding 72618
# adding 72691
# adding 72759
# adding 72835
# adding 72881
# adding 72972
# adding 73035
# adding 73075
# adding 73137
# adding 73227
# adding 73260
# adding 73361
# adding 73456
# adding 73523
# adding 73584
# adding 73655
# adding 73721
# adding 73786
# adding 73848
# adding 73915
# adding 73985
# adding 73986
# adding 74096
# adding 74155
# adding 74200
# adding 74314
# adding 74381
# adding 74438
# adding 74479
# adding 74517
# adding 74602
# adding 74669
# adding 74777
# adding 74840
# adding 74908
# adding 74971
# adding 75037
# adding 75093
# adding 75168
# adding 75238
# adding 75304
# adding 75364
# adding 75436
# adding 75498
# adding 75558
# adding 75619
# adding 75700
# adding 75758
# adding 75768
# adding 75855
# adding 75962
# adding 75997
# adding 76097
# adding 76152
# adding 76203
# adding 76277
# adding 76336
# adding 76400
# adding 76476
# adding 76538
# adding 76599
# adding 76628
# adding 76703
# adding 76765
# adding 76867
# adding 76954
# adding 76968
# adding 77087
# adding 77152
# adding 77213
# adding 77285
# adding 77348
# adding 77411
# adding 77482
# adding 77497
# adding 77560
# adding 77680
# adding 77687
# adding 77771
# adding 77814
# adding 77895
# adding 78007
# adding 78075
# adding 78142
# adding 78209
# adding 78223
# adding 78292
# adding 78383
# adding 78468
# adding 78479
# adding 78588
# adding 78640
# adding 78723
# adding 78788
# adding 78808
# adding 78870
# adding 78975
# adding 79051
# adding 79082
# adding 79191
# adding 79208
# adding 79291
# adding 79397
# adding 79459
# adding 79491
# adding 79592
# adding 79660
# adding 79725
# adding 79749
# adding 79837
# adding 79871
# adding 79953
# adding 80022
# adding 80097
# adding 80173
# adding 80219
# adding 80262
# adding 80383
# adding 80418
# adding 80471
# adding 80533
# adding 80588
# adding 80686
# adding 80731
# adding 80803
# adding 80890
# adding 80963
# adding 81012
# adding 81113
# adding 81126
# adding 81208
# adding 81303
# adding 81322
# adding 81441
# adding 81450
# adding 81513
# adding 81600
# adding 81678
# adding 81715
# adding 81831
# adding 81894
# adding 81947
# adding 81986
# adding 82089
# adding 82119
# adding 82179
# adding 82267
# adding 82359
# adding 82375
# adding 82484
# adding 82556
# adding 82606
# adding 82662
# adding 82714
# adding 82786
# adding 82865
# adding 82939
# adding 83013
# adding 83035
# adding 83154
# adding 83160
# adding 83288
# adding 83301
# adding 83375
# adding 83447
# adding 83533
# adding 83616
# adding 83687
# adding 83750
# adding 83818
# adding 83884
# adding 83909
# adding 83983
# adding 84081
# adding 84102
# adding 84209
# adding 84279
# adding 84335
# adding 84375
# adding 84447
# adding 84542
# adding 84582
# adding 84672
# adding 84709
# adding 84758
# adding 84831
# adding 84929
# adding 85007
# adding 85067
# adding 85138
# adding 85202
# adding 85271
# adding 85337
# adding 85403
# adding 85467
# adding 85533
# adding 85600
# adding 85663
# adding 85729
# adding 85799
# adding 85861
# adding 85929
# adding 85989
# adding 86056
# adding 86095
# adding 86192
# adding 86197
# adding 86327
# adding 86346
# adding 86415
# adding 86524
# adding 86560
# adding 86622
# adding 86681
# adding 86787
# adding 86854
# adding 86903
# adding 86976
# adding 87114
# adding 87157
# adding 87208
# adding 87279
# adding 87343
# adding 87447
# adding 87458
# adding 87551
# adding 87626
# adding 87701
# adding 87748
# adding 87834
# adding 87868
# adding 87974
# adding 88033
# adding 88100
# adding 88115
# adding 88239
# adding 88306
# adding 88371
# adding 88432
# adding 88505
# adding 88569
# adding 88637
# adding 88696
# adding 88748
# adding 88808
# adding 88879
# adding 88960
# adding 88986
# adding 89096
# adding 89140
# adding 89224
# adding 89296
# adding 89362
# adding 89396
# adding 89493
# adding 89523
# adding 89607
# adding 89648
# adding 89748
# adding 89776
# adding 89861
# adding 89945
# adding 90023
# adding 90087
# adding 90131
# adding 90219
# adding 90285
# adding 90346
# adding 90382
# adding 90485
# adding 90489
# adding 90617
# adding 90682
# adding 90747
# adding 90813
# adding 90872
# adding 90947
# adding 90970
# adding 91050
# adding 91144
# adding 91192
# adding 91277
# adding 91343
# adding 91405
# adding 91474
# adding 91538
# adding 91594
# adding 91666
# adding 91705
# adding 91791
# adding 91871
# adding 91935
# adding 92002
# adding 92066
# adding 92122
# adding 92200
# adding 92267
# adding 92328
# adding 92398
# adding 92465
# adding 92523
# adding 92594
# adding 92662
# adding 92725
# adding 92793
# adding 92859
# adding 92862
# adding 92987
# adding 93023
# adding 93076
# adding 93128
# adding 93251
# adding 93278
# adding 93330
# adding 93454
# adding 93518
# adding 93587
# adding 93649
# adding 93674
# adding 93782
# adding 93846
# adding 93908
# adding 93926
# adding 94034
# adding 94105
# adding 94175
# adding 94209
# adding 94309
# adding 94338
# adding 94384
# adding 94476
# adding 94545
# adding 94604
# adding 94701
# adding 94775
# adding 94838
# adding 94862
# adding 94972
# adding 94992
# adding 95043
# adding 95126
# adding 95175
# adding 95244
# adding 95312
# adding 95408
# adding 95459
# adding 95527
# adding 95591
# adding 95695
# adding 95747
# adding 95770
# adding 95837
# adding 95904
# adding 95967
# adding 96067
# adding 96125
# adding 96225
# adding 96291
# adding 96334
# adding 96416
# adding 96442
# adding 96502
# adding 96621
# adding 96654
# adding 96702
# adding 96779
# adding 96840
# adding 96905
# adding 96957
# adding 97052
# adding 97100
# adding 97217
# adding 97282
# adding 97346
# adding 97379
# adding 97481
# adding 97547
# adding 97608
# adding 97666
# adding 97711
# adding 97807
# adding 97856
# adding 97934
# adding 97966
# adding 98021
# adding 98094
# adding 98186
# adding 98214
# adding 98334
# Time:  0:18:00.244159
# counted stepsize is : 1
# <class 'list'>
# adding 55491
# adding 81380
# adding 98341
# adding 74377
# adding 87565
# adding 22035
# adding 42838
# adding 18585
# adding 90558
# adding 60799
# adding 48
# adding 89
# adding 176
# adding 198
# adding 268
# adding 384
# adding 396
# adding 500
# adding 537
# adding 624
# adding 686
# adding 741
# adding 842
# adding 875
# adding 932
# adding 1035
# adding 1095
# adding 1135
# adding 1217
# adding 1288
# adding 1345
# adding 1403
# adding 1498
# adding 1553
# adding 1648
# adding 1689
# adding 1718
# adding 1827
# adding 1878
# adding 1924
# adding 2023
# adding 2073
# adding 2132
# adding 2179
# adding 2283
# adding 2317
# adding 2377
# adding 2469
# adding 2571
# adding 2631
# adding 2640
# adding 2770
# adding 2837
# adding 2845
# adding 2942
# adding 3012
# adding 3060
# adding 3143
# adding 3212
# adding 3242
# adding 3350
# adding 3428
# adding 3452
# adding 3557
# adding 3569
# adding 3634
# adding 3735
# adding 3780
# adding 3848
# adding 3906
# adding 4022
# adding 4032
# adding 4145
# adding 4162
# adding 4266
# adding 4306
# adding 4401
# adding 4473
# adding 4540
# adding 4586
# adding 4654
# adding 4729
# adding 4812
# adding 4875
# adding 4935
# adding 4995
# adding 5078
# adding 5119
# adding 5205
# adding 5279
# adding 5336
# adding 5351
# adding 5458
# adding 5495
# adding 5559
# adding 5664
# adding 5741
# adding 5773
# adding 5872
# adding 5897
# adding 6000
# adding 6070
# adding 6136
# adding 6189
# adding 6267
# adding 6321
# adding 6367
# adding 6448
# adding 6471
# adding 6538
# adding 6626
# adding 6728
# adding 6738
# adding 6809
# adding 6878
# adding 6952
# adding 7048
# adding 7103
# adding 7192
# adding 7257
# adding 7268
# adding 7378
# adding 7449
# adding 7517
# adding 7532
# adding 7654
# adding 7696
# adding 7743
# adding 7830
# adding 7914
# adding 7941
# adding 8044
# adding 8100
# adding 8167
# adding 8220
# adding 8278
# adding 8381
# adding 8446
# adding 8510
# adding 8542
# adding 8621
# adding 8706
# adding 8749
# adding 8784
# adding 8844
# adding 8970
# adding 8976
# adding 9098
# adding 9116
# adding 9174
# adding 9304
# adding 9340
# adding 9403
# adding 9443
# adding 9509
# adding 9581
# adding 9680
# adding 9710
# adding 9809
# adding 9894
# adding 9951
# adding 10013
# adding 10038
# adding 10158
# adding 10224
# adding 10293
# adding 10360
# adding 10422
# adding 10490
# adding 10559
# adding 10603
# adding 10687
# adding 10729
# adding 10760
# adding 10827
# adding 10954
# adding 10967
# adding 11067
# adding 11119
# adding 11158
# adding 11231
# adding 11301
# adding 11417
# adding 11461
# adding 11515
# adding 11560
# adding 11677
# adding 11717
# adding 11788
# adding 11821
# adding 11909
# adding 11961
# adding 12026
# adding 12118
# adding 12154
# adding 12212
# adding 12299
# adding 12403
# adding 12461
# adding 12513
# adding 12555
# adding 12665
# adding 12679
# adding 12797
# adding 12868
# adding 12893
# adding 12947
# adding 13015
# adding 13082
# adding 13188
# adding 13260
# adding 13318
# adding 13375
# adding 13460
# adding 13489
# adding 13536
# adding 13653
# adding 13697
# adding 13790
# adding 13859
# adding 13895
# adding 13931
# adding 14015
# adding 14074
# adding 14163
# adding 14232
# adding 14278
# adding 14324
# adding 14425
# adding 14476
# adding 14579
# adding 14647
# adding 14714
# adding 14775
# adding 14842
# adding 14853
# adding 14979
# adding 15039
# adding 15074
# adding 15152
# adding 15203
# adding 15251
# adding 15372
# adding 15426
# adding 15509
# adding 15540
# adding 15583
# adding 15649
# adding 15732
# adding 15833
# adding 15905
# adding 15971
# adding 16033
# adding 16103
# adding 16166
# adding 16232
# adding 16294
# adding 16367
# adding 16431
# adding 16471
# adding 16543
# adding 16568
# adding 16661
# adding 16730
# adding 16826
# adding 16890
# adding 16961
# adding 17024
# adding 17091
# adding 17156
# adding 17225
# adding 17245
# adding 17340
# adding 17414
# adding 17452
# adding 17504
# adding 17596
# adding 17684
# adding 17753
# adding 17817
# adding 17851
# adding 17900
# adding 17968
# adding 18041
# adding 18127
# adding 18182
# adding 18228
# adding 18319
# adding 18388
# adding 18452
# adding 18482
# adding 18604
# adding 18618
# adding 18696
# adding 18806
# adding 18859
# adding 18931
# adding 18973
# adding 19048
# adding 19101
# adding 19149
# adding 19235
# adding 19272
# adding 19351
# adding 19404
# adding 19525
# adding 19567
# adding 19667
# adding 19727
# adding 19770
# adding 19844
# adding 19917
# adding 19972
# adding 20049
# adding 20097
# adding 20166
# adding 20241
# adding 20297
# adding 20340
# adding 20435
# adding 20504
# adding 20559
# adding 20639
# adding 20687
# adding 20784
# adding 20819
# adding 20864
# adding 20948
# adding 21051
# adding 21119
# adding 21125
# adding 21226
# adding 21277
# adding 21338
# adding 21440
# adding 21476
# adding 21563
# adding 21630
# adding 21670
# adding 21746
# adding 21823
# adding 21894
# adding 21913
# adding 22019
# adding 22058
# adding 22120
# adding 22206
# adding 22254
# adding 22317
# adding 22439
# adding 22447
# adding 22568
# adding 22580
# adding 22676
# adding 22761
# adding 22802
# adding 22874
# adding 22934
# adding 23033
# adding 23051
# adding 23105
# adding 23213
# adding 23237
# adding 23326
# adding 23420
# adding 23464
# adding 23560
# adding 23624
# adding 23650
# adding 23696
# adding 23790
# adding 23873
# adding 23954
# adding 24003
# adding 24089
# adding 24146
# adding 24170
# adding 24269
# adding 24352
# adding 24416
# adding 24484
# adding 24550
# adding 24616
# adding 24638
# adding 24694
# adding 24754
# adding 24819
# adding 24946
# adding 24980
# adding 25059
# adding 25108
# adding 25182
# adding 25229
# adding 25343
# adding 25363
# adding 25453
# adding 25480
# adding 25563
# adding 25660
# adding 25716
# adding 25770
# adding 25837
# adding 25924
# adding 25957
# adding 26065
# adding 26076
# adding 26176
# adding 26236
# adding 26272
# adding 26397
# adding 26453
# adding 26503
# adding 26595
# adding 26607
# adding 26716
# adding 26779
# adding 26858
# adding 26906
# adding 26969
# adding 27055
# adding 27081
# adding 27190
# adding 27241
# adding 27306
# adding 27335
# adding 27450
# adding 27503
# adding 27564
# adding 27599
# adding 27671
# adding 27720
# adding 27837
# adding 27885
# adding 27936
# adding 27997
# adding 28105
# adding 28179
# adding 28246
# adding 28312
# adding 28377
# adding 28441
# adding 28511
# adding 28545
# adding 28578
# adding 28689
# adding 28741
# adding 28803
# adding 28904
# adding 28970
# adding 29035
# adding 29105
# adding 29168
# adding 29235
# adding 29303
# adding 29369
# adding 29433
# adding 29467
# adding 29561
# adding 29630
# adding 29698
# adding 29759
# adding 29830
# adding 29888
# adding 29961
# adding 30029
# adding 30093
# adding 30158
# adding 30175
# adding 30242
# adding 30348
# adding 30399
# adding 30488
# adding 30546
# adding 30611
# adding 30649
# adding 30747
# adding 30816
# adding 30851
# adding 30923
# adding 31011
# adding 31022
# adding 31115
# adding 31177
# adding 31282
# adding 31291
# adding 31408
# adding 31467
# adding 31541
# adding 31552
# adding 31665
# adding 31738
# adding 31786
# adding 31876
# adding 31943
# adding 32003
# adding 32034
# adding 32141
# adding 32177
# adding 32265
# adding 32294
# adding 32352
# adding 32407
# adding 32493
# adding 32575
# adding 32665
# adding 32670
# adding 32761
# adding 32815
# adding 32928
# adding 32993
# adding 33062
# adding 33107
# adding 33173
# adding 33241
# adding 33288
# adding 33353
# adding 33426
# adding 33524
# adding 33572
# adding 33600
# adding 33682
# adding 33737
# adding 33857
# adding 33893
# adding 33943
# adding 34027
# adding 34111
# adding 34126
# adding 34219
# adding 34269
# adding 34368
# adding 34426
# adding 34476
# adding 34551
# adding 34600
# adding 34698
# adding 34752
# adding 34803
# adding 34861
# adding 34971
# adding 35020
# adding 35111
# adding 35155
# adding 35233
# adding 35306
# adding 35326
# adding 35441
# adding 35444
# adding 35559
# adding 35632
# adding 35701
# adding 35746
# adding 35792
# adding 35848
# adding 35910
# adding 36018
# adding 36067
# adding 36125
# adding 36184
# adding 36299
# adding 36361
# adding 36436
# adding 36560
# adding 36598
# adding 36695
# adding 36719
# adding 36823
# adding 36853
# adding 36928
# adding 37022
# adding 37068
# adding 37109
# adding 37162
# adding 37285
# adding 37332
# adding 37378
# adding 37464
# adding 37525
# adding 37618
# adding 37682
# adding 37729
# adding 37755
# adding 37881
# adding 37925
# adding 38006
# adding 38034
# adding 38092
# adding 38152
# adding 38236
# adding 38344
# adding 38348
# adding 38426
# adding 38507
# adding 38592
# adding 38638
# adding 38683
# adding 38790
# adding 38835
# adding 38908
# adding 38962
# adding 39058
# adding 39177
# adding 39241
# adding 39308
# adding 39397
# adding 39450
# adding 39532
# adding 39544
# adding 39647
# adding 39718
# adding 39753
# adding 39831
# adding 39885
# adding 39992
# adding 40003
# adding 40126
# adding 40191
# adding 40257
# adding 40323
# adding 40389
# adding 40454
# adding 40514
# adding 40564
# adding 40655
# adding 40678
# adding 40758
# adding 40845
# adding 40862
# adding 40931
# adding 41046
# adding 41105
# adding 41163
# adding 41241
# adding 41298
# adding 41371
# adding 41447
# adding 41513
# adding 41579
# adding 41642
# adding 41651
# adding 41768
# adding 41792
# adding 41907
# adding 41974
# adding 42039
# adding 42043
# adding 42137
# adding 42221
# adding 42251
# adding 42346
# adding 42420
# adding 42487
# adding 42537
# adding 42591
# adding 42662
# adding 42766
# adding 42773
# adding 42885
# adding 42950
# adding 43025
# adding 43096
# adding 43138
# adding 43192
# adding 43289
# adding 43313
# adding 43382
# adding 43482
# adding 43509
# adding 43610
# adding 43635
# adding 43752
# adding 43810
# adding 43839
# adding 43949
# adding 43981
# adding 44073
# adding 44122
# adding 44210
# adding 44258
# adding 44316
# adding 44410
# adding 44470
# adding 44517
# adding 44601
# adding 44648
# adding 44694
# adding 44808
# adding 44839
# adding 44902
# adding 44995
# adding 45047
# adding 45120
# adding 45170
# adding 45273
# adding 45314
# adding 45350
# adding 45436
# adding 45522
# adding 45541
# adding 45613
# adding 45695
# adding 45745
# adding 45818
# adding 45910
# adding 45950
# adding 46059
# adding 46071
# adding 46176
# adding 46223
# adding 46327
# adding 46359
# adding 46426
# adding 46510
# adding 46578
# adding 46618
# adding 46717
# adding 46756
# adding 46854
# adding 46915
# adding 46958
# adding 47014
# adding 47080
# adding 47131
# adding 47207
# adding 47296
# ...
# adding 17091
# adding 17156
# adding 17225
# adding 17245
# adding 17340
# adding 17414
# adding 17452
# adding 17504
# adding 17596
# adding 17684
# adding 17753
# adding 17817
# adding 17851
# adding 17900
# adding 17968
# adding 18041
# adding 18127
# adding 18182
# adding 18228
# adding 18319
# adding 18388
# adding 18452
# adding 18482
# adding 18604
# adding 18618
# adding 18696
# adding 18806
# adding 18859
# adding 18931
# adding 18973
# adding 19048
# adding 19101
# adding 19149
# adding 19235
# adding 19272
# adding 19351
# adding 19404
# adding 19525
# adding 19567
# adding 19667
# adding 19727
# adding 19770
# adding 19844
# adding 19917
# adding 19972
# adding 20049
# adding 20097
# adding 20166
# adding 20241
# adding 20297
# adding 20340
# adding 20435
# adding 20504
# adding 20559
# adding 20639
# adding 20687
# adding 20784
# adding 20819
# adding 20864
# adding 20948
# adding 21051
# adding 21119
# adding 21125
# adding 21226
# adding 21277
# adding 21338
# adding 21440
# adding 21476
# adding 21563
# adding 21630
# adding 21670
# adding 21746
# adding 21823
# adding 21894
# adding 21913
# adding 22019
# adding 22058
# adding 22120
# adding 22206
# adding 22254
# adding 22317
# adding 22439
# adding 22447
# adding 22568
# adding 22580
# adding 22676
# adding 22802
# adding 22874
# adding 22934
# adding 23033
# adding 23051
# adding 23105
# adding 23213
# adding 23237
# adding 23326
# adding 23420
# adding 23464
# adding 23560
# adding 23624
# adding 23650
# adding 23696
# adding 23790
# adding 23873
# adding 23954
# adding 24003
# adding 24089
# adding 24146
# adding 24170
# adding 24269
# adding 24352
# adding 24416
# adding 24484
# adding 24550
# adding 24616
# adding 24638
# adding 24694
# adding 24754
# adding 24819
# adding 24946
# adding 24980
# adding 25059
# adding 25108
# adding 25182
# adding 25229
# adding 25343
# adding 25363
# adding 25453
# adding 25480
# adding 25563
# adding 25660
# adding 25716
# adding 25770
# adding 25837
# adding 25924
# adding 25957
# adding 26065
# adding 26076
# adding 26176
# adding 26236
# adding 26272
# adding 26397
# adding 26453
# adding 26503
# adding 26595
# adding 26607
# adding 26716
# adding 26779
# adding 26858
# adding 26906
# adding 26969
# adding 27055
# adding 27081
# adding 27190
# adding 27241
# adding 27306
# adding 27335
# adding 27450
# adding 27503
# adding 27564
# adding 27599
# adding 27671
# adding 27720
# adding 27837
# adding 27885
# adding 27936
# adding 27997
# adding 28105
# adding 28179
# adding 28246
# adding 28312
# adding 28377
# adding 28441
# adding 28511
# adding 28545
# adding 28578
# adding 28689
# adding 28741
# adding 28803
# adding 28904
# adding 28970
# adding 29035
# adding 29105
# adding 29168
# adding 29235
# adding 29303
# adding 29369
# adding 29433
# adding 29467
# adding 29561
# adding 29630
# adding 29698
# adding 29759
# adding 29830
# adding 29888
# adding 29961
# adding 30029
# adding 30093
# adding 30158
# adding 30175
# adding 30242
# adding 30348
# adding 30399
# adding 30488
# adding 30546
# adding 30611
# adding 30649
# adding 30747
# adding 30816
# adding 30851
# adding 30923
# adding 31011
# adding 31022
# adding 31115
# adding 31177
# adding 31282
# adding 31291
# adding 31408
# adding 31467
# adding 31541
# adding 31552
# adding 31665
# adding 31738
# adding 31786
# adding 31876
# adding 31943
# adding 32003
# adding 32034
# adding 32141
# adding 32177
# adding 32265
# adding 32294
# adding 32352
# adding 32407
# adding 32493
# adding 32575
# adding 32665
# adding 32670
# adding 32761
# adding 32815
# adding 32928
# adding 32993
# adding 33062
# adding 33107
# adding 33173
# adding 33241
# adding 33288
# adding 33353
# adding 33426
# adding 33524
# adding 33572
# adding 33600
# adding 33682
# adding 33737
# adding 33857
# adding 33893
# adding 33943
# adding 34027
# adding 34111
# adding 34126
# adding 34219
# adding 34269
# adding 34368
# adding 34426
# adding 34476
# adding 34551
# adding 34600
# adding 34698
# adding 34752
# adding 34803
# adding 34861
# adding 34971
# adding 35020
# adding 35111
# adding 35155
# adding 35233
# adding 35306
# adding 35326
# adding 35441
# adding 35444
# adding 35559
# adding 35632
# adding 35701
# adding 35746
# adding 35792
# adding 35848
# adding 35910
# adding 36018
# adding 36067
# adding 36125
# adding 36184
# adding 36299
# adding 36361
# adding 36428
# adding 36436
# adding 36560
# adding 36598
# adding 36695
# adding 36719
# adding 36823
# adding 36853
# adding 36928
# adding 37022
# adding 37068
# adding 37109
# adding 37162
# adding 37285
# adding 37332
# adding 37378
# adding 37464
# adding 37525
# adding 37618
# adding 37682
# adding 37729
# adding 37755
# adding 37881
# adding 37925
# adding 38006
# adding 38034
# adding 38092
# adding 38152
# adding 38236
# adding 38344
# adding 38348
# adding 38426
# adding 38507
# adding 38592
# adding 38638
# adding 38683
# adding 38790
# adding 38835
# adding 38908
# adding 38962
# adding 39058
# adding 39074
# adding 39177
# adding 39241
# adding 39308
# adding 39397
# adding 39450
# adding 39532
# adding 39544
# adding 39647
# adding 39718
# adding 39753
# adding 39831
# adding 39885
# adding 39992
# adding 40003
# adding 40126
# adding 40191
# adding 40257
# adding 40323
# adding 40389
# adding 40454
# adding 40514
# adding 40564
# adding 40655
# adding 40678
# adding 40758
# adding 40845
# adding 40862
# adding 40931
# adding 41046
# adding 41105
# adding 41163
# adding 41241
# adding 41298
# adding 41371
# adding 41447
# adding 41513
# adding 41579
# adding 41642
# adding 41651
# adding 41768
# adding 41792
# adding 41907
# adding 41974
# adding 42039
# adding 42043
# adding 42137
# adding 42221
# adding 42251
# adding 42346
# adding 42420
# adding 42487
# adding 42537
# adding 42591
# adding 42662
# adding 42766
# adding 42773
# adding 42885
# adding 42950
# adding 43025
# adding 43096
# adding 43138
# adding 43192
# adding 43289
# adding 43313
# adding 43382
# adding 43482
# adding 43509
# adding 43610
# adding 43635
# adding 43752
# adding 43810
# adding 43839
# adding 43949
# adding 43981
# adding 44073
# adding 44122
# adding 44210
# adding 44258
# adding 44316
# adding 44410
# adding 44470
# adding 44517
# adding 44601
# adding 44648
# adding 44694
# adding 44808
# adding 44839
# adding 44902
# adding 44995
# adding 45047
# adding 45120
# adding 45170
# adding 45273
# adding 45314
# adding 45350
# adding 45436
# adding 45522
# adding 45541
# adding 45613
# adding 45695
# adding 45745
# adding 45818
# adding 45910
# adding 45950
# adding 46059
# adding 46071
# adding 46176
# adding 46223
# adding 46327
# adding 46359
# adding 46426
# adding 46510
# adding 46578
# adding 46618
# adding 46717
# adding 46756
# adding 46854
# adding 46915
# adding 46958
# adding 47014
# adding 47080
# adding 47131
# adding 47207
# adding 47296
# adding 47385
# adding 47425
# adding 47504
# adding 47581
# adding 47612
# adding 47681
# adding 47738
# adding 47817
# adding 47858
# adding 47977
# adding 47992
# adding 48107
# adding 48150
# adding 48232
# adding 48301
# adding 48367
# adding 48395
# adding 48487
# adding 48513
# adding 48632
# adding 48684
# adding 48743
# adding 48807
# adding 48888
# adding 48936
# adding 49028
# adding 49059
# adding 49154
# adding 49193
# adding 49243
# adding 49306
# adding 49388
# adding 49446
# adding 49515
# adding 49578
# adding 49674
# adding 49701
# adding 49766
# adding 49852
# adding 49898
# adding 49995
# adding 50066
# adding 50099
# adding 50211
# adding 50276
# adding 50292
# adding 50383
# adding 50484
# adding 50548
# adding 50570
# adding 50686
# adding 50705
# adding 50802
# adding 50822
# adding 50910
# adding 51004
# adding 51033
# adding 51087
# adding 51189
# adding 51253
# adding 51300
# adding 51399
# adding 51416
# adding 51545
# adding 51610
# adding 51637
# adding 51740
# adding 51798
# adding 51843
# adding 51891
# adding 51962
# adding 52056
# adding 52126
# adding 52154
# adding 52332
# adding 52399
# adding 52458
# adding 52512
# adding 52542
# adding 52609
# adding 52682
# adding 52757
# adding 52836
# adding 52911
# adding 52948
# adding 53025
# adding 53064
# adding 53157
# adding 53204
# adding 53289
# adding 53393
# adding 53412
# adding 53516
# adding 53581
# adding 53656
# adding 53658
# adding 53783
# adding 53849
# adding 53871
# adding 53938
# adding 54027
# adding 54110
# adding 54135
# adding 54235
# adding 54289
# adding 54379
# adding 54447
# adding 54472
# adding 54528
# adding 54622
# adding 54651
# adding 54736
# adding 54817
# adding 54856
# adding 54942
# adding 55014
# adding 55102
# adding 55147
# adding 55239
# adding 55277
# adding 55369
# adding 55427
# adding 55452
# adding 55570
# adding 55633
# adding 55667
# adding 55732
# adding 55817
# adding 55867
# adding 55959
# adding 56032
# adding 56099
# adding 56158
# adding 56230
# adding 56282
# adding 56312
# adding 56415
# adding 56451
# adding 56519
# adding 56601
# adding 56650
# adding 56759
# adding 56774
# adding 56831
# adding 56940
# adding 56964
# adding 57047
# adding 57138
# adding 57215
# adding 57281
# adding 57353
# adding 57417
# adding 57484
# adding 57551
# adding 57617
# adding 57678
# adding 57722
# adding 57797
# adding 57869
# adding 57930
# adding 57990
# adding 58070
# adding 58101
# adding 58190
# adding 58235
# adding 58310
# adding 58363
# adding 58422
# adding 58478
# adding 58576
# adding 58672
# adding 58739
# adding 58760
# adding 58868
# adding 58899
# adding 58990
# adding 59027
# adding 59119
# adding 59142
# adding 59234
# adding 59332
# adding 59394
# adding 59463
# adding 59491
# adding 59583
# adding 59628
# adding 59695
# adding 59752
# adding 59831
# adding 59920
# adding 59963
# adding 60050
# adding 60095
# adding 60127
# adding 60237
# adding 60265
# adding 60362
# adding 60443
# adding 60515
# adding 60584
# adding 60600
# adding 60699
# adding 60762
# adding 60829
# adding 60885
# adding 60983
# adding 61046
# adding 61115
# adding 61140
# adding 61191
# adding 61299
# adding 61362
# adding 61398
# adding 61451
# adding 61557
# adding 61609
# adding 61658
# adding 61717
# adding 61840
# adding 61858
# adding 61935
# adding 62017
# adding 62068
# adding 62142
# adding 62195
# adding 62261
# adding 62368
# adding 62433
# adding 62447
# adding 62521
# adding 62584
# adding 62647
# adding 62740
# adding 62780
# adding 62858
# adding 62961
# adding 63011
# adding 63046
# adding 63127
# adding 63204
# adding 63293
# adding 63327
# adding 63404
# adding 63491
# adding 63524
# adding 63623
# adding 63626
# adding 63745
# adding 63796
# adding 63879
# adding 63950
# adding 64016
# adding 64056
# adding 64151
# adding 64184
# adding 64255
# adding 64299
# adding 64406
# adding 64467
# adding 64496
# adding 64598
# adding 64625
# adding 64737
# adding 64802
# adding 64865
# adding 64887
# adding 64985
# adding 65043
# adding 65108
# adding 65160
# adding 65265
# adding 65281
# adding 65404
# adding 65469
# adding 65537
# adding 65540
# adding 65612
# adding 65686
# adding 65798
# adding 65830
# adding 65897
# adding 65974
# adding 66047
# adding 66125
# adding 66182
# adding 66225
# adding 66277
# adding 66371
# adding 66513
# adding 66590
# adding 66650
# adding 66666
# adding 66727
# adding 66856
# adding 66923
# adding 66989
# adding 67054
# adding 67079
# adding 67187
# adding 67253
# adding 67279
# adding 67321
# adding 67410
# adding 67461
# adding 67530
# adding 67649
# adding 67650
# adding 67781
# adding 67782
# adding 67897
# adding 67976
# adding 68011
# adding 68048
# adding 68163
# adding 68225
# adding 68283
# adding 68359
# adding 68421
# adding 68507
# adding 68570
# adding 68607
# adding 68693
# adding 68739
# adding 68825
# adding 68859
# adding 68936
# adding 68977
# adding 69101
# adding 69165
# adding 69173
# adding 69247
# adding 69323
# adding 69369
# adding 69468
# adding 69561
# adding 69594
# adding 69639
# adding 69716
# adding 69782
# adding 69837
# adding 69900
# adding 70025
# adding 70091
# adding 70150
# adding 70182
# adding 70288
# adding 70291
# adding 70409
# adding 70482
# adding 70552
# adding 70594
# adding 70667
# adding 70724
# adding 70773
# adding 70849
# adding 70949
# adding 70982
# adding 71036
# adding 71088
# adding 71187
# adding 71279
# adding 71342
# adding 71385
# adding 71445
# adding 71487
# adding 71575
# adding 71641
# adding 71739
# adding 71753
# adding 71852
# adding 71922
# adding 71962
# adding 72011
# adding 72079
# adding 72192
# adding 72246
# adding 72294
# adding 72358
# adding 72461
# adding 72498
# adding 72590
# adding 72618
# adding 72691
# adding 72759
# adding 72835
# adding 72881
# adding 72972
# adding 73035
# adding 73075
# adding 73137
# adding 73227
# adding 73260
# adding 73361
# adding 73456
# adding 73523
# adding 73584
# adding 73655
# adding 73721
# adding 73786
# adding 73848
# adding 73915
# adding 73985
# adding 73986
# adding 74096
# adding 74155
# adding 74200
# adding 74314
# adding 74381
# adding 74438
# adding 74479
# adding 74517
# adding 74602
# adding 74669
# adding 74777
# adding 74840
# adding 74908
# adding 74971
# adding 75037
# adding 75093
# adding 75168
# adding 75238
# adding 75304
# adding 75364
# adding 75436
# adding 75498
# adding 75558
# adding 75619
# adding 75700
# adding 75758
# adding 75768
# adding 75855
# adding 75962
# adding 75997
# adding 76097
# adding 76152
# adding 76203
# adding 76277
# adding 76336
# adding 76400
# adding 76476
# adding 76538
# adding 76599
# adding 76628
# adding 76703
# adding 76765
# adding 76867
# adding 76954
# adding 76968
# adding 77087
# adding 77152
# adding 77213
# adding 77285
# adding 77348
# adding 77411
# adding 77482
# adding 77497
# adding 77560
# adding 77680
# adding 77687
# adding 77771
# adding 77814
# adding 77895
# adding 78007
# adding 78075
# adding 78142
# adding 78209
# adding 78223
# adding 78292
# adding 78383
# adding 78468
# adding 78479
# adding 78588
# adding 78640
# adding 78723
# adding 78788
# adding 78808
# adding 78870
# adding 78975
# adding 79051
# adding 79082
# adding 79191
# adding 79208
# adding 79291
# adding 79397
# adding 79459
# adding 79491
# adding 79592
# adding 79660
# adding 79725
# adding 79749
# adding 79837
# adding 79871
# adding 79953
# adding 80022
# adding 80097
# adding 80173
# adding 80219
# adding 80262
# adding 80383
# adding 80418
# adding 80471
# adding 80533
# adding 80588
# adding 80686
# adding 80731
# adding 80803
# adding 80890
# adding 80963
# adding 81012
# adding 81113
# adding 81126
# adding 81208
# adding 81303
# adding 81322
# adding 81441
# adding 81450
# adding 81513
# adding 81600
# adding 81678
# adding 81715
# adding 81831
# adding 81894
# adding 81947
# adding 81986
# adding 82089
# adding 82119
# adding 82179
# adding 82267
# adding 82359
# adding 82375
# adding 82484
# adding 82556
# adding 82606
# adding 82662
# adding 82714
# adding 82786
# adding 82865
# adding 82939
# adding 83013
# adding 83035
# adding 83154
# adding 83160
# adding 83288
# adding 83301
# adding 83375
# adding 83447
# adding 83533
# adding 83616
# adding 83687
# adding 83750
# adding 83818
# adding 83884
# adding 83909
# adding 83983
# adding 84081
# adding 84102
# adding 84209
# adding 84279
# adding 84335
# adding 84375
# adding 84447
# adding 84542
# adding 84582
# adding 84672
# adding 84709
# adding 84758
# adding 84831
# adding 84929
# adding 85007
# adding 85067
# adding 85138
# adding 85202
# adding 85271
# adding 85337
# adding 85403
# adding 85467
# adding 85533
# adding 85600
# adding 85663
# adding 85729
# adding 85799
# adding 85861
# adding 85929
# adding 85989
# adding 86056
# adding 86095
# adding 86192
# adding 86197
# adding 86327
# adding 86346
# adding 86415
# adding 86524
# adding 86560
# adding 86622
# adding 86681
# adding 86787
# adding 86854
# adding 86903
# adding 86976
# adding 87053
# adding 87114
# adding 87157
# adding 87208
# adding 87279
# adding 87343
# adding 87447
# adding 87458
# adding 87551
# adding 87626
# adding 87701
# adding 87748
# adding 87834
# adding 87868
# adding 87974
# adding 88033
# adding 88100
# adding 88115
# adding 88239
# adding 88306
# adding 88371
# adding 88432
# adding 88505
# adding 88569
# adding 88637
# adding 88696
# adding 88748
# adding 88808
# adding 88879
# adding 88960
# adding 88986
# adding 89096
# adding 89140
# adding 89224
# adding 89296
# adding 89362
# adding 89396
# adding 89493
# adding 89523
# adding 89607
# adding 89648
# adding 89748
# adding 89776
# adding 89861
# adding 89945
# adding 90023
# adding 90087
# adding 90131
# adding 90219
# adding 90285
# adding 90346
# adding 90382
# adding 90485
# adding 90489
# adding 90617
# adding 90682
# adding 90747
# adding 90813
# adding 90872
# adding 90947
# adding 90970
# adding 91050
# adding 91144
# adding 91192
# adding 91277
# adding 91343
# adding 91405
# adding 91474
# adding 91538
# adding 91594
# adding 91666
# adding 91705
# adding 91791
# adding 91871
# adding 91935
# adding 92002
# adding 92066
# adding 92122
# adding 92200
# adding 92267
# adding 92328
# adding 92398
# adding 92465
# adding 92523
# adding 92594
# adding 92662
# adding 92725
# adding 92793
# adding 92859
# adding 92862
# adding 92987
# adding 93023
# adding 93076
# adding 93128
# adding 93251
# adding 93278
# adding 93330
# adding 93454
# adding 93518
# adding 93587
# adding 93649
# adding 93674
# adding 93782
# adding 93846
# adding 93908
# adding 93926
# adding 94034
# adding 94105
# adding 94175
# adding 94209
# adding 94309
# adding 94338
# adding 94384
# adding 94476
# adding 94545
# adding 94604
# adding 94701
# adding 94775
# adding 94838
# adding 94862
# adding 94972
# adding 94992
# adding 95043
# adding 95126
# adding 95175
# adding 95244
# adding 95312
# adding 95408
# adding 95459
# adding 95527
# adding 95591
# adding 95695
# adding 95747
# adding 95770
# adding 95837
# adding 95904
# adding 95967
# adding 96067
# adding 96125
# adding 96225
# adding 96291
# adding 96334
# adding 96416
# adding 96442
# adding 96502
# adding 96621
# adding 96654
# adding 96702
# adding 96779
# adding 96840
# adding 96905
# adding 96957
# adding 97052
# adding 97100
# adding 97217
# adding 97282
# adding 97346
# adding 97379
# adding 97481
# adding 97547
# adding 97608
# adding 97666
# adding 97711
# adding 97807
# adding 97856
# adding 97934
# adding 97966
# adding 98021
# adding 98094
# adding 98186
# adding 98214
# adding 98334
# Time:  0:18:51.628061

# %%
sizes_without_last = sizes[0:-1]

# %%
sizes_without_last
# Out:
# array([ 600,  700,  800,  900, 1000, 1100, 1200, 1300, 1400])

# %%
make_all_sets
