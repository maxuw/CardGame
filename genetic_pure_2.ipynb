# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sklearn

from datetime import datetime

# %matplotlib inline

# %%
from random import randint
from random import getrandbits
from random import sample
from random import choice
from random import random

# %%
best_results = pd.DataFrame()

# %%
scores = pd.DataFrame()

# %%
### Variables
ammount_genes_on = 1500
length_features = 100000
amount_chromosomes = 20
generation_number = 0
number_generations = 10
chromosome_mutation_rate = 0.4
gene_mutation_probability = 0.6
run_number = 0
# cycle = randint(0, 1000)

#bests
chromosome_best = []
r2_score_best = []
top_score = 0.16

### Save State
history = []

# %%
# from google.colab import drive
# drive.mount('/content/gdrive')

# %%
import time
import multiprocessing 
import smtplib

# %%
from multiprocessing import Process, Lock
from multiprocessing.sharedctypes import Array, Value

# %%
# Read data and present
tr_url = "https://raw.githubusercontent.com/maxuw/CardGame/master/trainingData.csv"
va_url = "https://raw.githubusercontent.com/maxuw/CardGame/master/validationData.csv"

train = pd.read_csv(tr_url)
valid = pd.read_csv(va_url)

# %%
# Helper functions to preprocess data to bag-of-cards format

def unnest(df, col):
    unnested = (df.apply(lambda x: pd.Series(x[col]), axis=1)
                .stack()
                .reset_index(level=1, drop=True))
    unnested.name = col
    return df.drop(col, axis=1).join(unnested)

def to_bag_of_cards(df):
    df['ind'] = np.arange(df.shape[0])# + 1
    df_orig = df.copy()
    df['deck'] = df['deck'].apply(lambda d: d.split(';'))
    df = unnest(df, 'deck')
    df['value'] = 1
    df_bag = df.pivot(index='ind', columns='deck', values='value')
    df_bag[df_bag.isna()] = 0
    df_bag = df_bag.astype('int')
    return pd.concat([df_orig.set_index('ind'), df_bag], axis=1)

# %%
bag_train = to_bag_of_cards(train)
bag_valid = to_bag_of_cards(valid)

# %%
# Specify example model fitting function and R squared metric

from sklearn.svm import SVR

def R2(x, y):
    return 1 - np.sum(np.square(x - y)) / np.sum(np.square(y - np.mean(y)))

def fit_svm(data):
    svr = SVR(kernel='rbf', gamma=1.0/90, C=1.0, epsilon=0.02, shrinking=False)
    svr.fit(data.drop(['deck', 'nofGames', 'nOfPlayers', 'winRate'], axis=1), data['winRate'])
    return svr

sizes = (np.arange(10) + 6) * 100

# %%
def create_chromosome(genes_on = 0, length = 0, indexes = []):
#     print(indexes)
    
    if length == 0:
        length = length_features

    if genes_on == 0:
        genes_on = ammount_genes_on
    
    if indexes == []:
    


        N = length # 
        K = genes_on # zeros N-K ones

        arr = np.array([False] * (N-K) + [True] * K, dtype=np.bool)

        np.random.shuffle(arr)
        #         print(np.sum(arr))
        
    else:
        sample_index = sample(indexes, ammount_genes_on)
        arr = np.array([False] * length)
        arr[sample_index] = True
#         print("created sample equals", np.where(arr==True)[:15])
        
    return arr

# %%
def create_population(indexes = []):
    
        
    population = []

    for i in range(amount_chromosomes):
        chromosome_new = create_chromosome(indexes=indexes)

        population.append(chromosome_new)

    history.append(population)
    return population

# %%
# def crossover_old(chrom0, chrom1):
#     crossover_start_time = datetime.now()
#     length_chrom = len(chrom0)
    

#     new_child = np.full(length_chrom, False, dtype=bool)
#     crossover_beginning_time = datetime.now() - crossover_start_time
    
#     loop_time_start = datetime.now()
#     for i in range(len(chrom0)):
#         if chrom0[i] == chrom1[i]:
#             new_child[i] = chrom0[i]
#         elif randint(0,1) == 0:
#             new_child[i] = chrom0[i]
#         else:
#             new_child[i] = chrom1[i]
    
#     loop_time = datetime.now() - loop_time_start
    
    
#     fixing_time_start = datetime.now()
# #     new_child = fix_child(new_child)
#     fixing_time = datetime.now() - fixing_time_start
    
#     print("Crossover: beginning: ", crossover_beginning_time, "Loop time: ", loop_time, "Fixing time: ", fixing_time)
    
#     return new_child

# %%
def crossover(chrom1, chrom2, genes_on=0):
    
    if genes_on == 0:
        genes_on = ammount_genes_on

    
    # where they are the same
    chrom_child = np.logical_and(chrom1, chrom2)
#     print(np.where(chrom_child))
    
    if np.sum(chrom_child) < genes_on:
        
        # potential genes
        list_potential_genes = np.where(chrom1 != chrom2)
        list_potential_genes = list(list_potential_genes[0])
    #     print(list_potential_genes)

        length_needed_fill_in = genes_on - np.sum(chrom_child)
#         print("length needed: ", length_needed_fill_in, "Genes_on_needed : ", genes_on, "on in child: ", np.sum(chrom_child))

        if length_needed_fill_in > 0:
            sample_to_change = sample(list_potential_genes, length_needed_fill_in)
    #         print(sample_to_change)

            chrom_child[sample_to_change] = True
    
    return chrom_child

# %%
def crossover_step(population):
    children = []
#     children.append(population[0])
    for i in range(amount_chromosomes):
        child = crossover(population[0], population[1])
        children.append(child)

    return children

# %%
def sort_population(population, population_rates):

    print("best chromosome in the population rate: ", max(population_rates))
    sorted_y_idx_list = sorted(range(len(population_rates)),key=lambda x:population_rates[x])
    sorted_y_idx_list.reverse()
    Xs = [population[i] for i in sorted_y_idx_list ]
    
    
    
    global chromosome_best
    chromosome_best = Xs[0]
    
    global r2_score_best
    r2_score_best = max(population_rates)  
    
#     print("top chromosome in the population: ", Xs[0])
    
    return Xs
    
#     sorted_population = [x for _,x in sorted(zip(population_rates, population))]
#     print(sorted_population)
# #     sorted_population.reverse()
# #     while population_rates != []:

# #         max_elem = max(population_rates)
# #         max_index = population_rates.index(max_elem)
# #         print("appending", max_index)
# #         sorted_population.append(population[max_index])
# #         print("deleting", max_index)
# #         del population_rates[max_index]
#     print(sorted_population)
#     return sorted_population

# %%
def mutate(chrom, mutation_amount=0):
    
    if mutation_amount == 0:
        mutation_amount = int(ammount_genes_on * gene_mutation_probability)
    
#     print(np.where(chrom))
#     print(np.where(chromosome_best))
    
    chrom_true = np.where(chrom==True)
    chrom_true = chrom_true[0].tolist()
    sample_true = sample(chrom_true, mutation_amount)

    chrom_false = np.where(chrom==False)
    chrom_false = chrom_false[0].tolist()
    sample_false = sample(chrom_false, mutation_amount)

    chrom[sample_true] = False
    chrom[sample_false] = True
    
    return chrom

# %%
# def mutate_old(chrom):
# #         print("were mutating something")
#     mutation_genes_amount = int(length_features * gene_mutation_probability)
# #         print(mutation_genes_amount)

#     N = length_features # 
#     K = mutation_genes_amount # zeros N-K ones

#     arr = np.array([False] * (N-K) + [True] * K, dtype=np.bool)

#     np.random.shuffle(arr)

#     indexes = np.where(arr == True)
# #         print(indexes)

#     changes = np.invert(chrom[indexes])

#     chrom[indexes] = changes

#     return chrom

# %%
def mutation_cycle(population):
    mutated_population = []
    
    mutation_count = 0
    
    for i in range(len(population)):
        
#         if i == 0:
#             mutated_population.append(population[i])
#             print("we don't mutate the best chromosome")
        
#         else:
        
        if random() < chromosome_mutation_rate:
#             print("a chromosome was selected to be mutated")
            mutated_chrom = mutate(population[i])            
            mutated_population.append(mutated_chrom)
            mutation_count += 1

        else:
            mutated_population.append(population[i])
    
    print("Number of chromosomes selected to be mutated this turn :", mutation_count)
    return mutated_population

# %%
def get_indexes(self, chrom=""):
    if chrom != "":
        indexes = np.where(chrom == True)
    else:
        indexes = np.where(population[0] == True)
    return indexes

# %%
from multiprocessing import Process, Lock
from multiprocessing.sharedctypes import Array


def multiprocess_rank(i, chromosome, sharedarray):
    
    indexes = np.where(chromosome == True)
#     print("indexes in the multi loop", indexes[0][:5])
#     print(indexes[:5])

    df = bag_train.loc[indexes]
#     print(df)

#         df = self.create_df(chromosome, data)
    model = fit_svm(df)
#     print(model)
    pred = model.predict(bag_valid.drop(['deck', 'nofGames', 'nOfPlayers', 'winRate'], axis=1))
#     print("predictions: ", pred)
    r2 = R2(pred, bag_valid['winRate'])
#     print(r2)
#         sharedarray[i] = r2
    sharedarray[i] = r2

# %%
def main(list_chromosomes):
    lock = Lock()
    array = Array('d', len(list_chromosomes), lock=lock)
    if __name__ == '__main__':
        for i in range(len(list_chromosomes)):
            chromosome = list_chromosomes[i]
#             print(chromosome)
            p = Process(target=multiprocess_rank, args=(i, chromosome, array))
            p.start()
            p.join()
    return list(array)


def evaluate_population(list_chromosomes):
    list_multi = main(list_chromosomes)
    
#     print("self population rates in encapsulate evaluate", list_multi)
        
#     max_list = max(list_multi)
#     print("max list", max_list)

#     max_index = list_multi.index(max_list)
#         best_now = max(zip(self.population_rates.values(), self.population_rates.keys()))
#     print("max_index", max_index)
#     print(list_multi)
    return list_multi

# %%
def save_best_chromosome():
    print("saving best chromosome")
    
    header = "genesOn: " + str(ammount_genes_on), "score ", str(r2_score_best), "countedGenes:", str(get_count_on(chromosome_best)), "chromosomes", str(amount_chromosomes), "generations", str(number_generations), "__genes", "\n\n",  "\n\n\n"
    header = str(header)
    content = get_indexes(chromosome_best)
    print("length of the saved best chromosome: ", len(content))
    
    file_characteristics = "genesOn: ", str(ammount_genes_on),  "score ", str(r2_score_best), "countedGenes:", str(get_count_on(chromosome_best)), "__"
    file_characteristics = str(file_characteristics)
    
    random_number = str(randint(0, 1000))
    directory = "Saves_jan1/"
#     print(type(file_characteristics))
    filename = directory + file_characteristics + random_number + ".csv"
    
    content_series = pd.Series(content)
    index = content
#     np.savetxt("file.txt", content)
    content_series.to_csv(filename, header=False)

# %%
def save_population(population):
    print("saving population")
    file_characteristics = "Population_genesOn: ", str(ammount_genes_on),  "score ", str(r2_score_best), "countedGenes:", str(get_count_on(population_best)), "__"
    file_characteristics = str(file_characteristics)
    
    directory = "Saves/"
    filename_np = directory + file_characteristics
#     filename_pd = directory + file_characteristics + ".csv"
#     filename_pd_indexes = directory + file_characteristics + "index.csv"
    
    
    np.savetxt(filename_np, population)
    
    
#     df.to_csv(filename_pd)

#     indexes = np.where(population[0] == True)
#     df.to_csv(filename_pd)

# %%
def load_population(file):
    
    population = np.loadtxt(file)
    
    return population

# %%
def train_predict_old(deck):
    model = fit_svm(deck)
    pred = model.predict(bag_valid.drop(['deck', 'nofGames', 'nOfPlayers', 'winRate'], axis=1))
    r2 = R2(pred, valid['winRate'])
    
    return r2

# %%
def train_predict(deck):
    start_time = datetime.now()
    model = fit_svm(deck)
    pred = model.predict(valid.drop(['deck', 'nofGames', 'nOfPlayers', 'winRate'], axis=1))
    r2 = R2(pred, valid['winRate'])
    end_time = datetime.now()
    time_taken = end_time - start_time
    print("training and predicting model:", time_taken)
    return(r2)

# %%
def evaluate_alone_sp(chromosome):
    indexes = np.where(chromosome == True)
    df = bag_train.loc[indexes]
    model = fit_svm(df)
    pred = model.predict(bag_valid.drop(['deck', 'nofGames', 'nOfPlayers', 'winRate'], axis=1))
    r2 = R2(pred, bag_valid['winRate'])
    print(r2)

# %%
def cycle(best_indexes = []):
    global generation_number
    generation_number = 0
    
    global run_number
    run_number = randint(0, 1000)
    
    total_start_time = datetime.now()
    generation_number = 0
    
    population = create_population(best_indexes)
    
    while generation_number < number_generations:
            
        population = gen_cycle(population)
        print("finished cycle")
        
#         print(get_indexes(chromosome_best))
        
    evaluation = evaluate_population(population)
    
    print("finished evaluating population")
    population = sort_population(population, evaluation)
    print(np.sum(population[0] == True))
    
    total_end_time = datetime.now()
    total_time_taken = total_end_time - total_start_time

    print('Total time: ', total_time_taken)
    
    return population

# %%
def email_details():

    server = smtplib.SMTP('smtp.gmail.com', 587)
    server.starttls()
    server.login("maxpythonuw@gmail.com", "")
    
    
    msg = "genesOn: ", ammount_genes_on, "score ", r2_score_best, "countedGenes:", get_count_on(chromosome_best), "chromosomes", amount_chromosomes, "generations", number_generations, "__genes", "\n\n",  "\n\n\n", get_indexes(chromosome_best)
    msg = str(msg)
    
    print(msg)
    server.sendmail("maxpythonuw@gmail.com", "m.jackl@student.uw.edu.pl", msg)
    server.quit()

# %%
def save_email():
    if rank_best > 0.19:
        save_best_chromosome()
        email_details()

# %%
def gen_cycle(population):
    cycle_start_time = datetime.now()
    
    evaluation = evaluate_population(population)
    evaluation_time = datetime.now() - cycle_start_time
    
    best_chromosome_to_list_best()
    
    sort_population_time_start = datetime.now()
    population = sort_population(population, evaluation)
    sort_population_time = datetime.now() - sort_population_time_start
    
    crossover_time_start = datetime.now()
    population = crossover_step(population)
    crossover_time = datetime.now() - crossover_time_start
    
    mutation_cycle_time_start = datetime.now()
    population = mutation_cycle(population)
    mutation_cycle_time = datetime.now() - mutation_cycle_time_start
    
    ending_start = datetime.now()
    history.append(population)
    
    global generation_number
    generation_number += 1
    ending_time = datetime.now() - ending_start

    cycle_end_time = datetime.now()
    time_taken = cycle_end_time - cycle_start_time
    
    best_chromosome_to_list_best()
    
    if r2_score_best > 0.18:
        save_best_chromosome()

    print("cycle: ", generation_number, time_taken, "Evaluation:", evaluation_time, "sortPop: ", sort_population_time, "Crossover: ", crossover_time, "mutationTime: ", mutation_cycle_time, "Ending: ", ending_time)
    
    return population

# %%
def get_indexes(chromosome):
    
    indexes = []
    list_ch = chromosome
    for i in range(len(list_ch)):
        if list_ch[i] == True:
            indexes.append(i)

    return indexes

# %%
def get_count_on(chromosome):
    # assumes it's sorted
#     chromosome = population[0]
    sum = np.sum(chromosome == True)
    return sum

# %%
def best_chromosome_to_list_best():
    global best_results
    global scores
#     if type(best_results) != pandas.core.frame.DataFrame:
#         best_results = pd.DataFrame()
    
    chromosome_indexes = np.where(chromosome_best==True)
    chromosome_indexes = chromosome_indexes[0]
    chromosome_indexes = chromosome_indexes.tolist()
    
    if chromosome_indexes != []:
        if r2_score_best > top_score:
            best_results = best_results.append(pd.Series({"Genes On":ammount_genes_on, "Score": r2_score_best, "Chromosome" : chromosome_indexes, "Run": run_number}), ignore_index=True)
        
        else:
            scores = scores.append(pd.Series({"Genes On":ammount_genes_on, "Score": r2_score_best, "Chromosome" : chromosome_indexes, "Run": run_number}), ignore_index=True)

# %%
def loan_numpy(file):
    load = np.loadtxt(file)
    load = load.astype(int)
    load = load.tolist()
    
    return load

# %%
best_results.sort_values("Score")
# Out:
#                                            Chromosome  Genes On    Run  \
# 0   [43, 83, 122, 186, 187, 354, 499, 522, 583, 69...    1500.0  883.0
# 1   [43, 83, 122, 186, 187, 354, 499, 522, 583, 69...    1500.0  883.0
# 14  [146, 248, 278, 431, 498, 508, 522, 621, 622, ...    1500.0  616.0
# 13  [146, 248, 278, 431, 498, 508, 522, 621, 622, ...    1500.0  616.0
# 12  [43, 83, 122, 186, 187, 354, 499, 522, 583, 69...    1500.0  883.0
# 11  [43, 83, 122, 186, 187, 354, 499, 522, 583, 69...    1500.0  883.0
# 10  [43, 83, 122, 186, 187, 354, 499, 522, 583, 69...    1500.0  883.0
# 8   [43, 83, 122, 186, 187, 354, 499, 522, 583, 69...    1500.0  883.0
# 9   [43, 83, 122, 186, 187, 354, 499, 522, 583, 69...    1500.0  883.0
# 6   [43, 83, 122, 186, 187, 354, 499, 522, 583, 69...    1500.0  883.0
# 5   [43, 83, 122, 186, 187, 354, 499, 522, 583, 69...    1500.0  883.0
# 4   [43, 83, 122, 186, 187, 354, 499, 522, 583, 69...    1500.0  883.0
# 3   [43, 83, 122, 186, 187, 354, 499, 522, 583, 69...    1500.0  883.0
# 2   [43, 83, 122, 186, 187, 354, 499, 522, 583, 69...    1500.0  883.0
# 7   [43, 83, 122, 186, 187, 354, 499, 522, 583, 69...    1500.0  883.0
# 15  [146, 248, 278, 431, 498, 508, 522, 621, 622, ...    1500.0  616.0
# 16  [146, 248, 278, 431, 498, 508, 522, 621, 622, ...    1500.0  616.0
# 18  [146, 248, 278, 431, 498, 508, 522, 621, 622, ...    1500.0  616.0
# 17  [146, 248, 278, 431, 498, 508, 522, 621, 622, ...    1500.0  616.0
# 19  [146, 248, 278, 431, 498, 508, 522, 621, 622, ...    1500.0  616.0
#
#        Score
# 0   0.160483
# 1   0.160483
# 14  0.161180
# 13  0.161180
# 12  0.161772
# 11  0.161772
# 10  0.161772
# 8   0.161772
# 9   0.161772
# 6   0.161772
# 5   0.161772
# 4   0.161772
# 3   0.161772
# 2   0.161772
# 7   0.161772
# 15  0.164600
# 16  0.164600
# 18  0.165958
# 17  0.165958
# 19  0.166643

# %%
# genetic = cycle()

# %%
# jan1 = loan_numpy("Jan_dumps/random_ind.out")

# %%
# best_results["Chromosome"].index[1]
# Out:
# 1

# %%
# best = best_results["Chromosome"]

# %%
# best.loc[1]

# %%
def dataframe_extract_all_sets(row_numbers, df):
    lists = []
    for row in row_numbers:
        list_ = dataframe_extract(row, df)
    lists.append(list_)
    return lists

# %%
def dataframe_extract(row_number, df_results):
    
    list = df_results["Chromosome"]
    list = list.loc[row_number]

    
    return list

# %%
# dataframe_extract(1, best_results)

# %%
best_chromosome_to_list_best()

# %%
train_predict(bag_train.loc[jan2])

# %%
# bag_train = bag_train.loc[jan2]

# %%
# population4 = cycle()

# %%
targets = [600, 700, 800, 900, 1000, 1100, 1200, 1300, 1400, 1500]

# %%
for target in targets:
    ammount_genes_on = target
    
    cycle(jan1)
# Out:
# best chromosome in the population rate:  0.21578044370841054
# Number of chromosomes selected to be mutated this turn : 9
# saving best chromosome
# length of the saved best chromosome:  600
# cycle:  1 0:00:10.582233 Evaluation: 0:00:10.511472 sortPop:  0:00:00.000226 Crossover:  0:00:00.017401 mutationTime:  0:00:00.053071 Ending:  0:00:00.000006
# finished cycle
# best chromosome in the population rate:  0.21496419824595114
# Number of chromosomes selected to be mutated this turn : 6
# saving best chromosome
# length of the saved best chromosome:  600
# cycle:  2 0:00:10.838840 Evaluation: 0:00:10.792045 sortPop:  0:00:00.000669 Crossover:  0:00:00.013492 mutationTime:  0:00:00.027710 Ending:  0:00:00.000006
# finished cycle
# best chromosome in the population rate:  0.21941597613771735
# Number of chromosomes selected to be mutated this turn : 7
# saving best chromosome
# length of the saved best chromosome:  600
# cycle:  3 0:00:10.591285 Evaluation: 0:00:10.539236 sortPop:  0:00:00.000190 Crossover:  0:00:00.011721 mutationTime:  0:00:00.034896 Ending:  0:00:00.000005
# finished cycle
# best chromosome in the population rate:  0.22483935171674596
# Number of chromosomes selected to be mutated this turn : 7
# saving best chromosome
# length of the saved best chromosome:  600
# cycle:  4 0:00:10.477849 Evaluation: 0:00:10.428530 sortPop:  0:00:00.000195 Crossover:  0:00:00.010767 mutationTime:  0:00:00.033047 Ending:  0:00:00.000005
# finished cycle
# best chromosome in the population rate:  0.22716036454932653
# Number of chromosomes selected to be mutated this turn : 11
# saving best chromosome
# length of the saved best chromosome:  600
# cycle:  5 0:00:10.790769 Evaluation: 0:00:10.722547 sortPop:  0:00:00.000188 Crossover:  0:00:00.010410 mutationTime:  0:00:00.052495 Ending:  0:00:00.000006
# finished cycle
# best chromosome in the population rate:  0.22989440402341343
# Number of chromosomes selected to be mutated this turn : 3
# saving best chromosome
# length of the saved best chromosome:  600
# cycle:  6 0:00:11.277020 Evaluation: 0:00:11.246167 sortPop:  0:00:00.000208 Crossover:  0:00:00.010307 mutationTime:  0:00:00.015179 Ending:  0:00:00.000005
# finished cycle
# best chromosome in the population rate:  0.23224787652519274
# Number of chromosomes selected to be mutated this turn : 8
# saving best chromosome
# length of the saved best chromosome:  600
# cycle:  7 0:00:11.035417 Evaluation: 0:00:10.981332 sortPop:  0:00:00.000290 Crossover:  0:00:00.010065 mutationTime:  0:00:00.038313 Ending:  0:00:00.000004
# finished cycle
# best chromosome in the population rate:  0.23375768318528445
# Number of chromosomes selected to be mutated this turn : 10
# saving best chromosome
# length of the saved best chromosome:  600
# cycle:  8 0:00:10.592357 Evaluation: 0:00:10.529625 sortPop:  0:00:00.000585 Crossover:  0:00:00.009218 mutationTime:  0:00:00.047500 Ending:  0:00:00.000006
# finished cycle
# best chromosome in the population rate:  0.23449569534334025
# Number of chromosomes selected to be mutated this turn : 9
# saving best chromosome
# length of the saved best chromosome:  600
# cycle:  9 0:00:11.133826 Evaluation: 0:00:11.074075 sortPop:  0:00:00.000182 Crossover:  0:00:00.009748 mutationTime:  0:00:00.044680 Ending:  0:00:00.000002
# finished cycle
# best chromosome in the population rate:  0.23492195252892922
# Number of chromosomes selected to be mutated this turn : 8
# saving best chromosome
# length of the saved best chromosome:  600
# cycle:  10 0:00:11.217565 Evaluation: 0:00:11.170432 sortPop:  0:00:00.000179 Crossover:  0:00:00.003791 mutationTime:  0:00:00.038071 Ending:  0:00:00.000006
# finished cycle
# finished evaluating population
# best chromosome in the population rate:  0.23492195252892922
# 600
# Total time:  0:02:01.037484
# best chromosome in the population rate:  0.2379428947036749
# Number of chromosomes selected to be mutated this turn : 11
# saving best chromosome
# length of the saved best chromosome:  700
# cycle:  1 0:00:13.021813 Evaluation: 0:00:12.898494 sortPop:  0:00:00.000220 Crossover:  0:00:00.023827 mutationTime:  0:00:00.092728 Ending:  0:00:00.000007
# finished cycle
# best chromosome in the population rate:  0.24260019074514594
# Number of chromosomes selected to be mutated this turn : 7
# saving best chromosome
# length of the saved best chromosome:  700
# cycle:  2 0:00:12.763029 Evaluation: 0:00:12.700904 sortPop:  0:00:00.000216 Crossover:  0:00:00.015545 mutationTime:  0:00:00.039315 Ending:  0:00:00.000007
# finished cycle
# best chromosome in the population rate:  0.23871182954138337
# Number of chromosomes selected to be mutated this turn : 10
# saving best chromosome
# length of the saved best chromosome:  700
# cycle:  3 0:00:12.990889 Evaluation: 0:00:12.894347 sortPop:  0:00:00.000308 Crossover:  0:00:00.020763 mutationTime:  0:00:00.067087 Ending:  0:00:00.000009
# finished cycle
# best chromosome in the population rate:  0.2501118217385311
# Number of chromosomes selected to be mutated this turn : 13
# saving best chromosome
# length of the saved best chromosome:  700
# cycle:  4 0:00:13.577027 Evaluation: 0:00:13.442380 sortPop:  0:00:00.000298 Crossover:  0:00:00.015297 mutationTime:  0:00:00.105698 Ending:  0:00:00.000009
# finished cycle
# best chromosome in the population rate:  0.25057783894631835
# Number of chromosomes selected to be mutated this turn : 9
# saving best chromosome
# length of the saved best chromosome:  700
# cycle:  5 0:00:12.925475 Evaluation: 0:00:12.859233 sortPop:  0:00:00.000223 Crossover:  0:00:00.011254 mutationTime:  0:00:00.048739 Ending:  0:00:00.000007
# finished cycle
# best chromosome in the population rate:  0.251279163937036
# Number of chromosomes selected to be mutated this turn : 5
# saving best chromosome
# length of the saved best chromosome:  700
# cycle:  6 0:00:12.829047 Evaluation: 0:00:12.788496 sortPop:  0:00:00.000228 Crossover:  0:00:00.010184 mutationTime:  0:00:00.025049 Ending:  0:00:00.000005
# finished cycle
# best chromosome in the population rate:  0.25235309057233046
# Number of chromosomes selected to be mutated this turn : 10
# saving best chromosome
# length of the saved best chromosome:  700
# cycle:  7 0:00:11.858747 Evaluation: 0:00:11.787319 sortPop:  0:00:00.000182 Crossover:  0:00:00.009623 mutationTime:  0:00:00.056480 Ending:  0:00:00.000007
# finished cycle
# best chromosome in the population rate:  0.25309313397380917
# Number of chromosomes selected to be mutated this turn : 7
# saving best chromosome
# length of the saved best chromosome:  700
# cycle:  8 0:00:11.430467 Evaluation: 0:00:11.381691 sortPop:  0:00:00.000170 Crossover:  0:00:00.009456 mutationTime:  0:00:00.033999 Ending:  0:00:00.000002
# finished cycle
# best chromosome in the population rate:  0.25309313397380917
# Number of chromosomes selected to be mutated this turn : 7
# saving best chromosome
# length of the saved best chromosome:  700
# cycle:  9 0:00:11.490779 Evaluation: 0:00:11.447691 sortPop:  0:00:00.000722 Crossover:  0:00:00.003504 mutationTime:  0:00:00.033801 Ending:  0:00:00.000005
# finished cycle
# best chromosome in the population rate:  0.25309313397380917
# Number of chromosomes selected to be mutated this turn : 7
# saving best chromosome
# length of the saved best chromosome:  700
# cycle:  10 0:00:11.383697 Evaluation: 0:00:11.340880 sortPop:  0:00:00.000179 Crossover:  0:00:00.003777 mutationTime:  0:00:00.033977 Ending:  0:00:00.000007
# finished cycle
# finished evaluating population
# best chromosome in the population rate:  0.25309313397380917
# 700
# Total time:  0:02:18.408475
# best chromosome in the population rate:  0.25380177268772786
# Number of chromosomes selected to be mutated this turn : 3
# saving best chromosome
# length of the saved best chromosome:  800
# cycle:  1 0:00:13.637829 Evaluation: 0:00:13.594969 sortPop:  0:00:00.000218 Crossover:  0:00:00.020386 mutationTime:  0:00:00.016359 Ending:  0:00:00.000006
# finished cycle
# best chromosome in the population rate:  0.2516048250865398
# Number of chromosomes selected to be mutated this turn : 6
# saving best chromosome
# length of the saved best chromosome:  800
# cycle:  2 0:00:14.144705 Evaluation: 0:00:14.042542 sortPop:  0:00:00.000437 Crossover:  0:00:00.025412 mutationTime:  0:00:00.059859 Ending:  0:00:00.000011
# finished cycle
# best chromosome in the population rate:  0.2571075103127446
# Number of chromosomes selected to be mutated this turn : 6
# saving best chromosome
# length of the saved best chromosome:  800
# cycle:  3 0:00:15.341175 Evaluation: 0:00:15.282031 sortPop:  0:00:00.000229 Crossover:  0:00:00.014861 mutationTime:  0:00:00.038216 Ending:  0:00:00.000013
# finished cycle
# best chromosome in the population rate:  0.2645267970048909
# Number of chromosomes selected to be mutated this turn : 7
# saving best chromosome
# length of the saved best chromosome:  800
# cycle:  4 0:00:16.189178 Evaluation: 0:00:16.124362 sortPop:  0:00:00.000305 Crossover:  0:00:00.017375 mutationTime:  0:00:00.038368 Ending:  0:00:00.000007
# finished cycle
# best chromosome in the population rate:  0.2685107142765467
# Number of chromosomes selected to be mutated this turn : 8
# saving best chromosome
# length of the saved best chromosome:  800
# cycle:  5 0:00:15.430091 Evaluation: 0:00:15.367072 sortPop:  0:00:00.000238 Crossover:  0:00:00.011342 mutationTime:  0:00:00.045812 Ending:  0:00:00.000008
# finished cycle
# best chromosome in the population rate:  0.27015268157078876
# Number of chromosomes selected to be mutated this turn : 3
# saving best chromosome
# length of the saved best chromosome:  800
# cycle:  6 0:00:16.220153 Evaluation: 0:00:16.178121 sortPop:  0:00:00.000258 Crossover:  0:00:00.011468 mutationTime:  0:00:00.023004 Ending:  0:00:00.000008
# finished cycle
# best chromosome in the population rate:  0.2711443106539104
# Number of chromosomes selected to be mutated this turn : 6
# saving best chromosome
# length of the saved best chromosome:  800
# cycle:  7 0:00:17.762130 Evaluation: 0:00:17.696408 sortPop:  0:00:00.000234 Crossover:  0:00:00.012471 mutationTime:  0:00:00.045291 Ending:  0:00:00.000009
# finished cycle
# best chromosome in the population rate:  0.2712480698074944
# Number of chromosomes selected to be mutated this turn : 8
# saving best chromosome
# length of the saved best chromosome:  800
# cycle:  8 0:00:17.416238 Evaluation: 0:00:17.338237 sortPop:  0:00:00.000329 Crossover:  0:00:00.006442 mutationTime:  0:00:00.061084 Ending:  0:00:00.000008
# finished cycle
# best chromosome in the population rate:  0.2712480698074944
# Number of chromosomes selected to be mutated this turn : 6
# saving best chromosome
# length of the saved best chromosome:  800
# cycle:  9 0:00:17.829356 Evaluation: 0:00:17.777419 sortPop:  0:00:00.000352 Crossover:  0:00:00.005932 mutationTime:  0:00:00.039213 Ending:  0:00:00.000011
# finished cycle
# best chromosome in the population rate:  0.2712480698074944
# Number of chromosomes selected to be mutated this turn : 5
# saving best chromosome
# length of the saved best chromosome:  800
# cycle:  10 0:00:17.721035 Evaluation: 0:00:17.666456 sortPop:  0:00:00.000255 Crossover:  0:00:00.004576 mutationTime:  0:00:00.042390 Ending:  0:00:00.000013
# finished cycle
# finished evaluating population
# best chromosome in the population rate:  0.2712480698074944
# 800
# Total time:  0:03:02.233535
# best chromosome in the population rate:  0.2671619524310609
# Number of chromosomes selected to be mutated this turn : 6
# saving best chromosome
# length of the saved best chromosome:  900
# cycle:  1 0:00:17.795471 Evaluation: 0:00:17.724790 sortPop:  0:00:00.000190 Crossover:  0:00:00.021599 mutationTime:  0:00:00.043065 Ending:  0:00:00.000008
# finished cycle
# best chromosome in the population rate:  0.2710945599878507
# Number of chromosomes selected to be mutated this turn : 10
# saving best chromosome
# length of the saved best chromosome:  900
# cycle:  2 0:00:20.305786 Evaluation: 0:00:20.206846 sortPop:  0:00:00.000794 Crossover:  0:00:00.016442 mutationTime:  0:00:00.075747 Ending:  0:00:00.000014
# finished cycle
# best chromosome in the population rate:  0.2706158212299463
# Number of chromosomes selected to be mutated this turn : 8
# saving best chromosome
# length of the saved best chromosome:  900
# cycle:  3 0:00:19.487934 Evaluation: 0:00:19.409869 sortPop:  0:00:00.000223 Crossover:  0:00:00.014394 mutationTime:  0:00:00.057155 Ending:  0:00:00.000007
# finished cycle
# best chromosome in the population rate:  0.27699240620648513
# Number of chromosomes selected to be mutated this turn : 6
# saving best chromosome
# length of the saved best chromosome:  900
# cycle:  4 0:00:19.891145 Evaluation: 0:00:19.758049 sortPop:  0:00:00.000679 Crossover:  0:00:00.031525 mutationTime:  0:00:00.085705 Ending:  0:00:00.000011
# finished cycle
# best chromosome in the population rate:  0.27668215303801846
# Number of chromosomes selected to be mutated this turn : 6
# saving best chromosome
# length of the saved best chromosome:  900
# cycle:  5 0:00:22.301515 Evaluation: 0:00:22.228903 sortPop:  0:00:00.000369 Crossover:  0:00:00.014973 mutationTime:  0:00:00.047630 Ending:  0:00:00.000006
# finished cycle
# best chromosome in the population rate:  0.27830562551669424
# Number of chromosomes selected to be mutated this turn : 11
# saving best chromosome
# length of the saved best chromosome:  900
# cycle:  6 0:00:22.265255 Evaluation: 0:00:22.152374 sortPop:  0:00:00.000285 Crossover:  0:00:00.017567 mutationTime:  0:00:00.088506 Ending:  0:00:00.000009
# finished cycle
# best chromosome in the population rate:  0.2787345537779914
# Number of chromosomes selected to be mutated this turn : 11
# saving best chromosome
# length of the saved best chromosome:  900
# cycle:  7 0:00:18.530748 Evaluation: 0:00:18.412835 sortPop:  0:00:00.000359 Crossover:  0:00:00.016989 mutationTime:  0:00:00.089421 Ending:  0:00:00.000015
# finished cycle
# best chromosome in the population rate:  0.2792071958028901
# Number of chromosomes selected to be mutated this turn : 8
# saving best chromosome
# length of the saved best chromosome:  900
# cycle:  8 0:00:18.572698 Evaluation: 0:00:18.508046 sortPop:  0:00:00.000209 Crossover:  0:00:00.011115 mutationTime:  0:00:00.047035 Ending:  0:00:00.000005
# finished cycle
# best chromosome in the population rate:  0.2791965812659086
# Number of chromosomes selected to be mutated this turn : 8
# saving best chromosome
# length of the saved best chromosome:  900
# cycle:  9 0:00:17.834251 Evaluation: 0:00:17.767867 sortPop:  0:00:00.000235 Crossover:  0:00:00.004772 mutationTime:  0:00:00.055138 Ending:  0:00:00.000005
# finished cycle
# best chromosome in the population rate:  0.2791965812659086
# Number of chromosomes selected to be mutated this turn : 11
# saving best chromosome
# length of the saved best chromosome:  900
# cycle:  10 0:00:20.378846 Evaluation: 0:00:20.188183 sortPop:  0:00:00.000942 Crossover:  0:00:00.009913 mutationTime:  0:00:00.159769 Ending:  0:00:00.000006
# finished cycle
# finished evaluating population
# best chromosome in the population rate:  0.2791965812659086
# 900
# Total time:  0:03:39.733669
# best chromosome in the population rate:  0.28411582755551124
# Number of chromosomes selected to be mutated this turn : 9
# saving best chromosome
# length of the saved best chromosome:  1000
# cycle:  1 0:00:20.059842 Evaluation: 0:00:19.968741 sortPop:  0:00:00.000282 Crossover:  0:00:00.027884 mutationTime:  0:00:00.054864 Ending:  0:00:00.000005
# finished cycle
# best chromosome in the population rate:  0.2809190072808253
# Number of chromosomes selected to be mutated this turn : 9
# saving best chromosome
# length of the saved best chromosome:  1000
# cycle:  2 0:00:21.045256 Evaluation: 0:00:20.947207 sortPop:  0:00:00.000326 Crossover:  0:00:00.019788 mutationTime:  0:00:00.068469 Ending:  0:00:00.000009
# finished cycle
# best chromosome in the population rate:  0.28583538004665743
# Number of chromosomes selected to be mutated this turn : 7
# saving best chromosome
# length of the saved best chromosome:  1000
# cycle:  3 0:00:20.842801 Evaluation: 0:00:20.775996 sortPop:  0:00:00.000282 Crossover:  0:00:00.014207 mutationTime:  0:00:00.045559 Ending:  0:00:00.000002
# finished cycle
# best chromosome in the population rate:  0.2891464139409965
# Number of chromosomes selected to be mutated this turn : 10
# saving best chromosome
# length of the saved best chromosome:  1000
# cycle:  4 0:00:19.792473 Evaluation: 0:00:19.699271 sortPop:  0:00:00.000763 Crossover:  0:00:00.017429 mutationTime:  0:00:00.066946 Ending:  0:00:00.000003
# finished cycle
# best chromosome in the population rate:  0.28922293558526246
# Number of chromosomes selected to be mutated this turn : 6
# saving best chromosome
# length of the saved best chromosome:  1000
# cycle:  5 0:00:19.532565 Evaluation: 0:00:19.464185 sortPop:  0:00:00.000371 Crossover:  0:00:00.018142 mutationTime:  0:00:00.039188 Ending:  0:00:00.000002
# finished cycle
# best chromosome in the population rate:  0.2904084057821633
# Number of chromosomes selected to be mutated this turn : 5
# saving best chromosome
# length of the saved best chromosome:  1000
# cycle:  6 0:00:20.372761 Evaluation: 0:00:20.316610 sortPop:  0:00:00.000227 Crossover:  0:00:00.012684 mutationTime:  0:00:00.034137 Ending:  0:00:00.000002
# finished cycle
# best chromosome in the population rate:  0.2909534539096188
# Number of chromosomes selected to be mutated this turn : 11
# saving best chromosome
# length of the saved best chromosome:  1000
# cycle:  7 0:00:19.755796 Evaluation: 0:00:19.659408 sortPop:  0:00:00.000216 Crossover:  0:00:00.011453 mutationTime:  0:00:00.078715 Ending:  0:00:00.000006
# finished cycle
# best chromosome in the population rate:  0.29127208932535475
# Number of chromosomes selected to be mutated this turn : 6
# saving best chromosome
# length of the saved best chromosome:  1000
# cycle:  8 0:00:20.025756 Evaluation: 0:00:19.932003 sortPop:  0:00:00.000336 Crossover:  0:00:00.017468 mutationTime:  0:00:00.065964 Ending:  0:00:00.000005
# finished cycle
# best chromosome in the population rate:  0.29138637167599457
# Number of chromosomes selected to be mutated this turn : 9
# saving best chromosome
# length of the saved best chromosome:  1000
# cycle:  9 0:00:20.114771 Evaluation: 0:00:20.040665 sortPop:  0:00:00.000240 Crossover:  0:00:00.004547 mutationTime:  0:00:00.062349 Ending:  0:00:00.000002
# finished cycle
# best chromosome in the population rate:  0.29138637167599457
# Number of chromosomes selected to be mutated this turn : 6
# saving best chromosome
# length of the saved best chromosome:  1000
# cycle:  10 0:00:19.265624 Evaluation: 0:00:19.219274 sortPop:  0:00:00.000275 Crossover:  0:00:00.004202 mutationTime:  0:00:00.036258 Ending:  0:00:00.000006
# finished cycle
# finished evaluating population
# best chromosome in the population rate:  0.29138637167599457
# 1000
# Total time:  0:03:42.959643
# best chromosome in the population rate:  0.29357459965053245
# Number of chromosomes selected to be mutated this turn : 7
# saving best chromosome
# length of the saved best chromosome:  1100
# cycle:  1 0:00:22.142167 Evaluation: 0:00:22.053258 sortPop:  0:00:00.000889 Crossover:  0:00:00.029015 mutationTime:  0:00:00.050285 Ending:  0:00:00.000002
# finished cycle
# best chromosome in the population rate:  0.2961902602615455
# Number of chromosomes selected to be mutated this turn : 7
# saving best chromosome
# length of the saved best chromosome:  1100
# cycle:  2 0:00:21.562749 Evaluation: 0:00:21.489363 sortPop:  0:00:00.000233 Crossover:  0:00:00.015342 mutationTime:  0:00:00.051704 Ending:  0:00:00.000003
# finished cycle
# best chromosome in the population rate:  0.2984702634538834
# Number of chromosomes selected to be mutated this turn : 11
# saving best chromosome
# length of the saved best chromosome:  1100
# cycle:  3 0:00:21.454990 Evaluation: 0:00:21.318902 sortPop:  0:00:00.000985 Crossover:  0:00:00.021420 mutationTime:  0:00:00.104169 Ending:  0:00:00.000006
# finished cycle
# best chromosome in the population rate:  0.2998693004666969
# Number of chromosomes selected to be mutated this turn : 8
# saving best chromosome
# length of the saved best chromosome:  1100
# cycle:  4 0:00:21.224149 Evaluation: 0:00:21.149528 sortPop:  0:00:00.000229 Crossover:  0:00:00.012540 mutationTime:  0:00:00.055323 Ending:  0:00:00.000004
# finished cycle
# best chromosome in the population rate:  0.30039510591653884
# Number of chromosomes selected to be mutated this turn : 7
# saving best chromosome
# length of the saved best chromosome:  1100
# cycle:  5 0:00:21.264773 Evaluation: 0:00:21.173000 sortPop:  0:00:00.000464 Crossover:  0:00:00.018565 mutationTime:  0:00:00.063499 Ending:  0:00:00.000005
# finished cycle
# best chromosome in the population rate:  0.30192327105866956
# Number of chromosomes selected to be mutated this turn : 7
# saving best chromosome
# length of the saved best chromosome:  1100
# cycle:  6 0:00:20.856915 Evaluation: 0:00:20.790423 sortPop:  0:00:00.000211 Crossover:  0:00:00.011470 mutationTime:  0:00:00.048808 Ending:  0:00:00.000005
# finished cycle
# best chromosome in the population rate:  0.30229786472764586
# Number of chromosomes selected to be mutated this turn : 9
# saving best chromosome
# length of the saved best chromosome:  1100
# cycle:  7 0:00:21.055548 Evaluation: 0:00:20.974833 sortPop:  0:00:00.000376 Crossover:  0:00:00.012480 mutationTime:  0:00:00.060369 Ending:  0:00:00.000009
# finished cycle
# best chromosome in the population rate:  0.30229786472764586
# Number of chromosomes selected to be mutated this turn : 13
# saving best chromosome
# length of the saved best chromosome:  1100
# cycle:  8 0:00:21.177615 Evaluation: 0:00:21.078904 sortPop:  0:00:00.000804 Crossover:  0:00:00.005186 mutationTime:  0:00:00.085034 Ending:  0:00:00.000008
# finished cycle
# best chromosome in the population rate:  0.30229786472764586
# Number of chromosomes selected to be mutated this turn : 11
# saving best chromosome
# length of the saved best chromosome:  1100
# cycle:  9 0:00:22.042467 Evaluation: 0:00:21.961555 sortPop:  0:00:00.000214 Crossover:  0:00:00.004404 mutationTime:  0:00:00.070314 Ending:  0:00:00.000009
# finished cycle
# best chromosome in the population rate:  0.30229786472764586
# Number of chromosomes selected to be mutated this turn : 7
# saving best chromosome
# length of the saved best chromosome:  1100
# cycle:  10 0:00:21.197730 Evaluation: 0:00:21.092171 sortPop:  0:00:00.000586 Crossover:  0:00:00.005138 mutationTime:  0:00:00.087828 Ending:  0:00:00.000020
# finished cycle
# finished evaluating population
# best chromosome in the population rate:  0.30229786472764586
# 1100
# Total time:  0:03:57.040611
# best chromosome in the population rate:  0.30225937398108815
# Number of chromosomes selected to be mutated this turn : 6
# saving best chromosome
# length of the saved best chromosome:  1200
# cycle:  1 0:00:25.245825 Evaluation: 0:00:25.137889 sortPop:  0:00:00.000337 Crossover:  0:00:00.033159 mutationTime:  0:00:00.067425 Ending:  0:00:00.000013
# finished cycle
# best chromosome in the population rate:  0.3052378575128625
# Number of chromosomes selected to be mutated this turn : 9
# saving best chromosome
# length of the saved best chromosome:  1200
# cycle:  2 0:00:24.964721 Evaluation: 0:00:24.847535 sortPop:  0:00:00.000287 Crossover:  0:00:00.024627 mutationTime:  0:00:00.083576 Ending:  0:00:00.000009
# finished cycle
# best chromosome in the population rate:  0.30570479924038474
# Number of chromosomes selected to be mutated this turn : 11
# saving best chromosome
# length of the saved best chromosome:  1200
# cycle:  3 0:00:23.932717 Evaluation: 0:00:23.844774 sortPop:  0:00:00.000206 Crossover:  0:00:00.012346 mutationTime:  0:00:00.069689 Ending:  0:00:00.000008
# finished cycle
# best chromosome in the population rate:  0.30686687162872595
# Number of chromosomes selected to be mutated this turn : 7
# saving best chromosome
# length of the saved best chromosome:  1200
# cycle:  4 0:00:24.792403 Evaluation: 0:00:24.704269 sortPop:  0:00:00.000860 Crossover:  0:00:00.015157 mutationTime:  0:00:00.064300 Ending:  0:00:00.000014
# finished cycle
# best chromosome in the population rate:  0.30744472951702895
# Number of chromosomes selected to be mutated this turn : 9
# saving best chromosome
# length of the saved best chromosome:  1200
# cycle:  5 0:00:24.446064 Evaluation: 0:00:24.351938 sortPop:  0:00:00.000322 Crossover:  0:00:00.018194 mutationTime:  0:00:00.065797 Ending:  0:00:00.000008
# finished cycle
# best chromosome in the population rate:  0.3081172890743319
# Number of chromosomes selected to be mutated this turn : 7
# saving best chromosome
# length of the saved best chromosome:  1200
# cycle:  6 0:00:23.061619 Evaluation: 0:00:22.995080 sortPop:  0:00:00.000221 Crossover:  0:00:00.011662 mutationTime:  0:00:00.048298 Ending:  0:00:00.000008
# finished cycle
# best chromosome in the population rate:  0.30828709082719696
# Number of chromosomes selected to be mutated this turn : 5
# saving best chromosome
# length of the saved best chromosome:  1200
# cycle:  7 0:00:23.699054 Evaluation: 0:00:23.646522 sortPop:  0:00:00.000853 Crossover:  0:00:00.011248 mutationTime:  0:00:00.034521 Ending:  0:00:00.000009
# finished cycle
# best chromosome in the population rate:  0.30834195082108684
# Number of chromosomes selected to be mutated this turn : 9
# saving best chromosome
# length of the saved best chromosome:  1200
# cycle:  8 0:00:22.720244 Evaluation: 0:00:22.651387 sortPop:  0:00:00.000275 Crossover:  0:00:00.004330 mutationTime:  0:00:00.058164 Ending:  0:00:00.000006
# finished cycle
# best chromosome in the population rate:  0.30834195082108684
# Number of chromosomes selected to be mutated this turn : 12
# saving best chromosome
# length of the saved best chromosome:  1200
# cycle:  9 0:00:23.079717 Evaluation: 0:00:22.990377 sortPop:  0:00:00.000220 Crossover:  0:00:00.004350 mutationTime:  0:00:00.078910 Ending:  0:00:00.000005
# finished cycle
# best chromosome in the population rate:  0.30834195082108684
# Number of chromosomes selected to be mutated this turn : 9
# saving best chromosome
# length of the saved best chromosome:  1200
# cycle:  10 0:00:22.908725 Evaluation: 0:00:22.822125 sortPop:  0:00:00.000314 Crossover:  0:00:00.006638 mutationTime:  0:00:00.070569 Ending:  0:00:00.000009
# finished cycle
# finished evaluating population
# best chromosome in the population rate:  0.30834195082108684
# 1200
# Total time:  0:04:23.991710
# best chromosome in the population rate:  0.3106760073415683
# Number of chromosomes selected to be mutated this turn : 8
# saving best chromosome
# length of the saved best chromosome:  1300
# cycle:  1 0:00:24.753198 Evaluation: 0:00:24.669136 sortPop:  0:00:00.000297 Crossover:  0:00:00.016895 mutationTime:  0:00:00.058084 Ending:  0:00:00.000009
# finished cycle
# best chromosome in the population rate:  0.3123814312124652
# Number of chromosomes selected to be mutated this turn : 5
# saving best chromosome
# length of the saved best chromosome:  1300
# cycle:  2 0:00:24.756606 Evaluation: 0:00:24.706365 sortPop:  0:00:00.000205 Crossover:  0:00:00.012631 mutationTime:  0:00:00.031735 Ending:  0:00:00.000011
# finished cycle
# best chromosome in the population rate:  0.314692316754027
# Number of chromosomes selected to be mutated this turn : 8
# saving best chromosome
# length of the saved best chromosome:  1300
# cycle:  3 0:00:25.164727 Evaluation: 0:00:25.089847 sortPop:  0:00:00.000202 Crossover:  0:00:00.013114 mutationTime:  0:00:00.054683 Ending:  0:00:00.000005
# finished cycle
# best chromosome in the population rate:  0.3157896246644719
# Number of chromosomes selected to be mutated this turn : 12
# saving best chromosome
# length of the saved best chromosome:  1300
# cycle:  4 0:00:26.356659 Evaluation: 0:00:26.228297 sortPop:  0:00:00.000346 Crossover:  0:00:00.019276 mutationTime:  0:00:00.098512 Ending:  0:00:00.000005
# finished cycle
# best chromosome in the population rate:  0.3159457821784105
# Number of chromosomes selected to be mutated this turn : 5
# saving best chromosome
# length of the saved best chromosome:  1300
# cycle:  5 0:00:25.689703 Evaluation: 0:00:25.637753 sortPop:  0:00:00.000216 Crossover:  0:00:00.011351 mutationTime:  0:00:00.034542 Ending:  0:00:00.000005
# finished cycle
# best chromosome in the population rate:  0.31621562328287733
# Number of chromosomes selected to be mutated this turn : 11
# saving best chromosome
# length of the saved best chromosome:  1300
# cycle:  6 0:00:26.224153 Evaluation: 0:00:26.006973 sortPop:  0:00:00.000315 Crossover:  0:00:00.023086 mutationTime:  0:00:00.183444 Ending:  0:00:00.000009
# finished cycle
# best chromosome in the population rate:  0.3162775664930656
# Number of chromosomes selected to be mutated this turn : 12
# saving best chromosome
# length of the saved best chromosome:  1300
# cycle:  7 0:00:26.148150 Evaluation: 0:00:26.034867 sortPop:  0:00:00.000339 Crossover:  0:00:00.016913 mutationTime:  0:00:00.086229 Ending:  0:00:00.000006
# finished cycle
# best chromosome in the population rate:  0.3162775664930656
# Number of chromosomes selected to be mutated this turn : 10
# saving best chromosome
# length of the saved best chromosome:  1300
# cycle:  8 0:00:25.470832 Evaluation: 0:00:25.363311 sortPop:  0:00:00.000270 Crossover:  0:00:00.006330 mutationTime:  0:00:00.094611 Ending:  0:00:00.000014
# finished cycle
# best chromosome in the population rate:  0.3162775664930656
# Number of chromosomes selected to be mutated this turn : 7
# saving best chromosome
# length of the saved best chromosome:  1300
# cycle:  9 0:00:29.499374 Evaluation: 0:00:29.425400 sortPop:  0:00:00.000314 Crossover:  0:00:00.005098 mutationTime:  0:00:00.061417 Ending:  0:00:00.000007
# finished cycle
# best chromosome in the population rate:  0.3162775664930656
# Number of chromosomes selected to be mutated this turn : 5
# saving best chromosome
# length of the saved best chromosome:  1300
# cycle:  10 0:00:29.329843 Evaluation: 0:00:29.281022 sortPop:  0:00:00.000288 Crossover:  0:00:00.004853 mutationTime:  0:00:00.037081 Ending:  0:00:00.000008
# finished cycle
# finished evaluating population
# best chromosome in the population rate:  0.3162775664930656
# 1300
# Total time:  0:04:51.770289
# best chromosome in the population rate:  0.316333750537403
# Number of chromosomes selected to be mutated this turn : 5
# saving best chromosome
# length of the saved best chromosome:  1400
# cycle:  1 0:00:28.787890 Evaluation: 0:00:28.706875 sortPop:  0:00:00.001018 Crossover:  0:00:00.021432 mutationTime:  0:00:00.049880 Ending:  0:00:00.000008
# finished cycle
# best chromosome in the population rate:  0.31866550035584595
# Number of chromosomes selected to be mutated this turn : 6
# saving best chromosome
# length of the saved best chromosome:  1400
# cycle:  2 0:00:28.654694 Evaluation: 0:00:28.575548 sortPop:  0:00:00.000807 Crossover:  0:00:00.020017 mutationTime:  0:00:00.049637 Ending:  0:00:00.000008
# finished cycle
# best chromosome in the population rate:  0.3195993788530048
# Number of chromosomes selected to be mutated this turn : 11
# saving best chromosome
# length of the saved best chromosome:  1400
# cycle:  3 0:00:28.599267 Evaluation: 0:00:28.502622 sortPop:  0:00:00.000252 Crossover:  0:00:00.012603 mutationTime:  0:00:00.077394 Ending:  0:00:00.000009
# finished cycle
# best chromosome in the population rate:  0.3203977731797256
# Number of chromosomes selected to be mutated this turn : 5
# saving best chromosome
# length of the saved best chromosome:  1400
# cycle:  4 0:00:29.042381 Evaluation: 0:00:28.964470 sortPop:  0:00:00.000304 Crossover:  0:00:00.015837 mutationTime:  0:00:00.052543 Ending:  0:00:00.000024
# finished cycle
# best chromosome in the population rate:  0.32043205167820343
# Number of chromosomes selected to be mutated this turn : 9
# saving best chromosome
# length of the saved best chromosome:  1400
# cycle:  5 0:00:28.432652 Evaluation: 0:00:28.350048 sortPop:  0:00:00.000211 Crossover:  0:00:00.010880 mutationTime:  0:00:00.065688 Ending:  0:00:00.000009
# finished cycle
# best chromosome in the population rate:  0.3204839056426314
# Number of chromosomes selected to be mutated this turn : 7
# saving best chromosome
# length of the saved best chromosome:  1400
# cycle:  6 0:00:29.287301 Evaluation: 0:00:29.213328 sortPop:  0:00:00.000339 Crossover:  0:00:00.016170 mutationTime:  0:00:00.047511 Ending:  0:00:00.000010
# finished cycle
# best chromosome in the population rate:  0.3204839056426314
# Number of chromosomes selected to be mutated this turn : 9
# saving best chromosome
# length of the saved best chromosome:  1400
# cycle:  7 0:00:28.961140 Evaluation: 0:00:28.881046 sortPop:  0:00:00.000952 Crossover:  0:00:00.004488 mutationTime:  0:00:00.068211 Ending:  0:00:00.000009
# finished cycle
# best chromosome in the population rate:  0.3204839056426314
# Number of chromosomes selected to be mutated this turn : 9
# saving best chromosome
# length of the saved best chromosome:  1400
# cycle:  8 0:00:29.440879 Evaluation: 0:00:29.337424 sortPop:  0:00:00.000362 Crossover:  0:00:00.004944 mutationTime:  0:00:00.089164 Ending:  0:00:00.000008
# finished cycle
# best chromosome in the population rate:  0.3204839056426314
# Number of chromosomes selected to be mutated this turn : 10
# saving best chromosome
# length of the saved best chromosome:  1400
# cycle:  9 0:00:29.640251 Evaluation: 0:00:29.521044 sortPop:  0:00:00.000475 Crossover:  0:00:00.006919 mutationTime:  0:00:00.100721 Ending:  0:00:00.000010
# finished cycle
# best chromosome in the population rate:  0.3204839056426314
# Number of chromosomes selected to be mutated this turn : 7
# saving best chromosome
# length of the saved best chromosome:  1400
# cycle:  10 0:00:29.468188 Evaluation: 0:00:29.362431 sortPop:  0:00:00.000313 Crossover:  0:00:00.006803 mutationTime:  0:00:00.088371 Ending:  0:00:00.000009
# finished cycle
# finished evaluating population
# best chromosome in the population rate:  0.3204839056426314
# 1400
# Total time:  0:05:20.867867
# best chromosome in the population rate:  0.3240657226697503
# Number of chromosomes selected to be mutated this turn : 9
# saving best chromosome
# length of the saved best chromosome:  1500
# cycle:  1 0:00:29.482903 Evaluation: 0:00:29.398279 sortPop:  0:00:00.000331 Crossover:  0:00:00.006683 mutationTime:  0:00:00.067693 Ending:  0:00:00.000009
# finished cycle
# best chromosome in the population rate:  0.3240657226697503
# Number of chromosomes selected to be mutated this turn : 11
# saving best chromosome
# length of the saved best chromosome:  1500
# cycle:  2 0:00:28.994089 Evaluation: 0:00:28.864155 sortPop:  0:00:00.000381 Crossover:  0:00:00.006459 mutationTime:  0:00:00.112276 Ending:  0:00:00.000011
# finished cycle
# best chromosome in the population rate:  0.3240657226697503
# Number of chromosomes selected to be mutated this turn : 6
# saving best chromosome
# length of the saved best chromosome:  1500
# cycle:  3 0:00:29.503946 Evaluation: 0:00:29.451151 sortPop:  0:00:00.000214 Crossover:  0:00:00.004323 mutationTime:  0:00:00.042204 Ending:  0:00:00.000013
# finished cycle
# best chromosome in the population rate:  0.3240657226697503
# Number of chromosomes selected to be mutated this turn : 9
# saving best chromosome
# length of the saved best chromosome:  1500
# cycle:  4 0:00:30.258556 Evaluation: 0:00:30.152825 sortPop:  0:00:00.000330 Crossover:  0:00:00.005910 mutationTime:  0:00:00.089893 Ending:  0:00:00.000012
# finished cycle
# best chromosome in the population rate:  0.3240657226697503
# Number of chromosomes selected to be mutated this turn : 5
# saving best chromosome
# length of the saved best chromosome:  1500
# cycle:  5 0:00:29.917571 Evaluation: 0:00:29.831513 sortPop:  0:00:00.000326 Crossover:  0:00:00.005937 mutationTime:  0:00:00.069233 Ending:  0:00:00.000023
# finished cycle
# best chromosome in the population rate:  0.3240657226697503
# Number of chromosomes selected to be mutated this turn : 9
# saving best chromosome
# length of the saved best chromosome:  1500
# cycle:  6 0:00:31.122034 Evaluation: 0:00:30.980796 sortPop:  0:00:00.000338 Crossover:  0:00:00.006917 mutationTime:  0:00:00.123718 Ending:  0:00:00.000012
# finished cycle
# best chromosome in the population rate:  0.3240657226697503
# Number of chromosomes selected to be mutated this turn : 7
# saving best chromosome
# length of the saved best chromosome:  1500
# cycle:  7 0:00:30.019148 Evaluation: 0:00:29.956027 sortPop:  0:00:00.000254 Crossover:  0:00:00.004160 mutationTime:  0:00:00.052853 Ending:  0:00:00.000013
# finished cycle
# best chromosome in the population rate:  0.3240657226697503
# Number of chromosomes selected to be mutated this turn : 9
# saving best chromosome
# length of the saved best chromosome:  1500
# cycle:  8 0:00:32.338471 Evaluation: 0:00:32.259123 sortPop:  0:00:00.000219 Crossover:  0:00:00.004519 mutationTime:  0:00:00.068432 Ending:  0:00:00.000006
# finished cycle
# best chromosome in the population rate:  0.3240657226697503
# Number of chromosomes selected to be mutated this turn : 5
# saving best chromosome
# length of the saved best chromosome:  1500
# cycle:  9 0:00:31.986657 Evaluation: 0:00:31.922248 sortPop:  0:00:00.000300 Crossover:  0:00:00.006288 mutationTime:  0:00:00.048988 Ending:  0:00:00.000006
# finished cycle
# best chromosome in the population rate:  0.3240657226697503
# Number of chromosomes selected to be mutated this turn : 10
# saving best chromosome
# length of the saved best chromosome:  1500
# cycle:  10 0:00:30.182848 Evaluation: 0:00:30.099640 sortPop:  0:00:00.000211 Crossover:  0:00:00.004621 mutationTime:  0:00:00.072338 Ending:  0:00:00.000008
# finished cycle
# finished evaluating population
# best chromosome in the population rate:  0.3240657226697503
# 1500
# Total time:  0:05:34.905939

# %%
# list_df

# %%
list_df = genetic_algorithm

# %%
targets =  [600, 700, 800, 900, 1000, 1100, 1200, 1300, 1400, 1500]

# %%
def create_random_sample():
    random_sample = []
    for target in targets:
        sample_chromosome = []
        is_target = list_df["Genes On"]==target
#         print(target)
        justTarget = list_df[is_target]
#         len(sample_chromosome = justTarget["Chromosome"].sample().tolist()[0])
        
        sample_chromosome = justTarget["Chromosome"].sample().tolist()[0]
        while len(sample_chromosome) != target:
            print(len(sample_chromosome))
            sample_chromosome = justTarget["Chromosome"].sample().tolist()[0]

        print(len(set(sample_chromosome)))
        print(len(set(sample_chromosome)))
        random_sample.append(sample_chromosome)
        
    return random_sample

# %%
def save_file_competition(sample, filename, directory="genetic/"):
    rand = randint(0,1000)
    filename = directory+filename+str(rand)+".txt"
    with open(filename, 'a') as f:
        for list_ in sample:
            ind_text = ','.join(list(map(str, list_)))
            text = ';'.join(['0.02', '1.0', str(1.0 / 90), ind_text])
            f.write(text + '\n')

# %%
def create_write_random():
    sample = create_random_sample()
    save_file_competition(sample, "genetic")

# %%
create_write_random()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-65-c615dfe0f774> in <module>
# ----> 1 create_write_random()
#
# NameError: name 'create_write_random' is not defined

# %%
def fit_svm(data):
    svr = SVR(kernel='rbf', gamma=1.0/90, C=1.0, epsilon=0.02, shrinking=False)
    svr.fit(data.drop(['deck', 'nofGames', 'nOfPlayers', 'winRate'], axis=1), data['winRate'])
    return svr

# %%
def train_predict_old(deck):
    model = fit_svm(deck)
    pred = model.predict(bag_valid.drop(['deck', 'nofGames', 'nOfPlayers', 'winRate'], axis=1))
    r2 = R2(pred, valid['winRate'])
    
    return r2

# %%
# {'C': [0.001, 0.01, 0.1, 1, 10, 100],
#           'gamma': [0.0001, 0.001, 0.01, 0.1],

# %%
def parameters_test(indexes):
    gamma = [1.0/90, 1.1/90, 1.2/90, 1.3/90, 1.4/90, 1.5/90, 2/90, 0.9/90, 0.8/90, 0.7/90, 0.5/90, 1.0/90]
    epsilon = [0, 0.01, 0.1, 0.02, 0.5, 1, 2, 4]
    C = npdata.tolist() #[0.1, 0.2, 0.3]

    for gam in gamma:
        for eps in epsilon:
            for c in C:
                
                r2 = train_varying_parameters(indexes, gam, c, eps)
                print(str(r2), "    Gamma: ", gam, "Eps: ", eps, "C ", c)

# %%
def train_varying_parameters(indexes, gamma=1.0/90, C=1.0, epsilon=0.02):    
    
    df = bag_train.loc[indexes]
    svr = SVR(kernel='rbf', gamma=gamma, C=C, epsilon=epsilon, shrinking=False)
    model = svr.fit(df.drop(['deck', 'nofGames', 'nOfPlayers', 'winRate'], axis=1), df['winRate'])
    pred = model.predict(bag_valid.drop(['deck', 'nofGames', 'nOfPlayers', 'winRate'], axis=1))
    r2 = R2(pred, valid['winRate'])
    
    return r2

# %%
train_varying_parameters(best_results["Chromosome"].loc[best_results["Score"].idxmax()])

# %%
parameters_test(best_results["Chromosome"].loc[best_results["Score"].idxmax()])

# %%
best_results.sort_values("Score", ascending=False).head()

# %%
best_results["Chromosome"].loc[best_results["Score"].idxmax()]

# %%
best_results.max(by="Score")

# %%
# Fit and predict on models of various training sizes

fit_list = list(map(lambda size: fit_svm(train.iloc[:size]), sizes))
pred_list = list(map(lambda fit: fit.predict(valid.drop(['deck', 'nofGames', 'nOfPlayers', 'winRate'], axis=1)),
                     fit_list))

# %%
import pickle

# %%
dict_best10000 = pickle.load( open( "pickles/best10000.pkl", "rb" ) )

# %%
for genes_on, value in dict_best10000.items():
    ammount_genes_on = genes_on
    cycle(value)
    print(list_best_chromosomes_best100000)

# %%
with open('pickles/gen_from_jan1.pkl', 'wb') as output:
    pickle.dump(best_results, output, -1)

# %%
results_best

# %%
scores
